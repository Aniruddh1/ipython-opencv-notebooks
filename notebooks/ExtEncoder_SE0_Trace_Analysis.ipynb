# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

import sys
from paths import Paths
paths = Paths()
sys.path.append(paths.scripts_root)
import util

import pandas as pd

# %load_ext autoreload
# %autoreload 2

# Display entire width of browser
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

paths.print_paths()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Paths defined in paths module:
#  paths.scripts_root: /Users/trafferty/data/scripts
#  paths.tmp_root: /Users/trafferty/data/tmp
#  paths.projects_root: /Users/trafferty/data/projects
#  paths.data_root: /Users/trafferty/data
#  paths.tmp_dir: /Users/trafferty/tmp
#  paths.mii_home: /Users/trafferty/dev
#  paths.results_root: /Users/trafferty/data/results
#  paths.images_root: /Users/trafferty/data/images
#  paths.inhouse: /Users/trafferty/dev/src/inhouse
#  paths.ws_dir: /Users/trafferty/workspace
#  paths.notebook_root: /Users/trafferty/data/notebooks

# %%
SE0_trace1_path=paths.tmp_root+'/SE0_trace1.CSV'
SE0_trace2_path=paths.tmp_root+'/SE0_trace2.CSV'

SE0_trace1=pd.read_csv(SE0_trace1_path).drop('CH2 Peak Detect', axis=1)
SE0_trace2=pd.read_csv(SE0_trace2_path).drop('CH2 Peak Detect', axis=1)

# %%
SE0_trace1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125000 entries, 0 to 124999
# Data columns (total 2 columns):
# TIME    125000 non-null float64
# CH2     125000 non-null float64
# dtypes: float64(2)
# memory usage: 1.9 MB

# %%
dispence_trace = SE0_trace1.loc[(SE0_trace1['TIME'] > -0.65) & (SE0_trace1['TIME'] < -0.25)]

# %%
min_time, max_time = -0.65, -0.25
min_time, max_time = -0.52, -0.39
dispence_trace = SE0_trace1.loc[(SE0_trace1['TIME'] > min_time) & (SE0_trace1['TIME'] < max_time)]
xticks = x=np.arange(min_time, max_time, (max_time-min_time)/50.0)
dispence_trace.plot(x='TIME', y='CH2', figsize=(30,20), grid=True, xticks=xticks, rot=45)
print("Time delta: %f - %f = %f" % (max_time, min_time, (max_time-min_time)))
# Out:
# Time delta: -0.390000 - -0.520000 = 0.130000

# %%
df = dispence_trace.reset_index()
df.Data > 4.0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-84403aae3dda> in <module>()
#       1 df = dispence_trace.reset_index()
# ----> 2 df.Data > 4.0
#
# ~/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Data'
