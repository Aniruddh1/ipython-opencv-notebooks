# %%
# %matplotlib inline
import time
import datetime
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import sys
import paths
sys.path.append(paths.scripts_root)
import util

# %load_ext autoreload
# %autoreload 2
import TTM_analysis_utils as TTMUtil

# Display entire width of browser
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
print("Paths:")
for k,v in paths.path.items():
    print(" path.%s: %s" % (k,v))

import glob
from collections import OrderedDict

debug = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Paths:
#  path.notebook_root: /Users/trafferty/data/notebooks
#  path.tmp_root: /Users/trafferty/data/tmp
#  path.images_root: /Users/trafferty/data/images
#  path.projects_root: /Users/trafferty/data/projects
#  path.tmp_dir: /Users/trafferty/tmp
#  path.scripts_root: /Users/trafferty/data/scripts
#  path.ws_dir: /Users/trafferty/workspace
#  path.results_root: /Users/trafferty/data/results

# %%
numCams = 4
cols, col_ids = TTMUtil.define_columns_and_ids(numCams, legacy)

print("cols:", cols)
print("\ncol_ids:", col_ids)
# Out:
# cols: ['TS', 'time_s', 'time_offset_s', 'numread', 'TTMNumComplete', 'TTMNumPartial', 'TTM_SerialNum', 'Cam1_TimeStamp', 'Cam2_TimeStamp', 'Cam3_TimeStamp', 'Cam4_TimeStamp', 'C0 measx_mm', 'C0 scorex', 'C0 measy_mm', 'C0 scorey', 'C0 cmeasx_mm', 'C0 cscorex', 'C0 cmeasy_mm', 'C0 cscorey', 'C0 x unwrap cnt', 'C0 y unwrap cnt', 'C0 post measx_mm', 'C0 post measy_mm', 'C0 post cmeasx_mm', 'C0 post cmeasy_mm', 'C1 measx_mm', 'C1 scorex', 'C1 measy_mm', 'C1 scorey', 'C1 cmeasx_mm', 'C1 cscorex', 'C1 cmeasy_mm', 'C1 cscorey', 'C1 x unwrap cnt', 'C1 y unwrap cnt', 'C1 post measx_mm', 'C1 post measy_mm', 'C1 post cmeasx_mm', 'C1 post cmeasy_mm', 'C2 measx_mm', 'C2 scorex', 'C2 measy_mm', 'C2 scorey', 'C2 cmeasx_mm', 'C2 cscorex', 'C2 cmeasy_mm', 'C2 cscorey', 'C2 x unwrap cnt', 'C2 y unwrap cnt', 'C2 post measx_mm', 'C2 post measy_mm', 'C2 post cmeasx_mm', 'C2 post cmeasy_mm', 'C3 measx_mm', 'C3 scorex', 'C3 measy_mm', 'C3 scorey', 'C3 cmeasx_mm', 'C3 cscorex', 'C3 cmeasy_mm', 'C3 cscorey',
# ...

# %%
trace_file_lst = [
    ('./trace_file_template/template.114207/wafer.1/imprint.1/TTMLogStream.1', '114207'),
    ('./trace_file_template/template.114208/wafer.1/imprint.1/TTMLogStream.1', '114208'),
    ('./trace_file_template/template.114209/wafer.1/imprint.1/TTMLogStream.1', '114209'),
    ('./trace_file_template/template.114210/wafer.1/imprint.1/TTMLogStream.1', '114210'),
    ('./trace_file_template/template.114211/wafer.1/imprint.1/TTMLogStream.1', '114211'),
    ('./trace_file_template/template.114212/wafer.1/imprint.1/TTMLogStream.1', '114212'),
    ('./trace_file_template/template.114213/wafer.1/imprint.1/TTMLogStream.1', '114213'),
    ('./trace_file_template/template.114214/wafer.1/imprint.1/TTMLogStream.1', '114214'),
    ('./trace_file_template/template.114215/wafer.1/imprint.1/TTMLogStream.1', '114215'),
    ('./trace_file_template/template.114216/wafer.1/imprint.1/TTMLogStream.1', '114216'),
    ('./trace_file_template/template.114217/wafer.1/imprint.1/TTMLogStream.1', '114217'),
    ('./trace_file_template/template.114218/wafer.1/imprint.1/TTMLogStream.1', '114218'),
    ('./trace_file_template/template.114219/wafer.1/imprint.1/TTMLogStream.1', '114219'),
    ('./trace_file_template/template.114220/wafer.1/imprint.1/TTMLogStream.1', '114220'),
    ('./trace_file_template/template.114221/wafer.1/imprint.1/TTMLogStream.1', '114221'),
    ('./trace_file_template/template.114222/wafer.1/imprint.1/TTMLogStream.1', '114222'),
    ('./trace_file_template/template.114223/wafer.1/imprint.1/TTMLogStream.1', '114223'),
    ('./trace_file_template/template.114224/wafer.1/imprint.1/TTMLogStream.1', '114224'),
    ('./trace_file_template/template.114225/wafer.1/imprint.1/TTMLogStream.1', '114225'),
    ('./trace_file_template/template.114226/wafer.1/imprint.1/TTMLogStream.1', '114226'),
    ('./trace_file_template/template.114227/wafer.1/imprint.1/TTMLogStream.1', '114227'),
    ('./trace_file_template/template.114228/wafer.1/imprint.1/TTMLogStream.1', '114228'),
    ('./trace_file_template/template.114229/wafer.1/imprint.1/TTMLogStream.1', '114229'),
    ('./trace_file_template/template.114230/wafer.1/imprint.1/TTMLogStream.1', '114230'),
    ('./trace_file_template/template.114231/wafer.1/imprint.1/TTMLogStream.1', '114231'),
    ('./trace_file_template/template.114232/wafer.1/imprint.1/TTMLogStream.1', '114232'),
    ('./trace_file_template/template.114233/wafer.1/imprint.1/TTMLogStream.1', '114233'),
    ('./trace_file_template/template.114234/wafer.1/imprint.1/TTMLogStream.1', '114234'),
    ('./trace_file_template/template.114235/wafer.1/imprint.1/TTMLogStream.1', '114235'),
    ('./trace_file_template/template.114236/wafer.1/imprint.1/TTMLogStream.1', '114236'),
    ('./trace_file_template/template.114237/wafer.1/imprint.1/TTMLogStream.1', '114237'),
    ('./trace_file_template/template.114238/wafer.1/imprint.1/TTMLogStream.1', '114238'),
    ('./trace_file_template/template.114239/wafer.1/imprint.1/TTMLogStream.1', '114239'),
    ('./trace_file_template/template.114240/wafer.1/imprint.1/TTMLogStream.1', '114240'),
    ('./trace_file_template/template.114241/wafer.1/imprint.1/TTMLogStream.1', '114241'),
    ('./trace_file_template/template.114242/wafer.1/imprint.1/TTMLogStream.1', '114242'),
    ('./trace_file_template/template.114243/wafer.1/imprint.1/TTMLogStream.1', '114243'),
    ('./trace_file_template/template.114244/wafer.1/imprint.1/TTMLogStream.1', '114244'),
    ('./trace_file_template/template.114245/wafer.1/imprint.1/TTMLogStream.1', '114245'),
    ('./trace_file_template/template.114246/wafer.1/imprint.1/TTMLogStream.1', '114246'),
    ('./trace_file_template/template.114247/wafer.1/imprint.1/TTMLogStream.1', '114247'),
    ('./trace_file_template/template.114248/wafer.1/imprint.1/TTMLogStream.1', '114248'),
    ('./trace_file_template/template.114249/wafer.1/imprint.1/TTMLogStream.1', '114249'),
    ('./trace_file_template/template.114250/wafer.1/imprint.1/TTMLogStream.1', '114250'),
    ('./trace_file_template/template.114251/wafer.1/imprint.1/TTMLogStream.1', '114251'),
    ('./trace_file_template/template.114252/wafer.1/imprint.1/TTMLogStream.1', '114252'),
    ('./trace_file_template/template.114253/wafer.1/imprint.1/TTMLogStream.1', '114253'),
    ('./trace_file_template/template.114254/wafer.1/imprint.1/TTMLogStream.1', '114254'),
    ('./trace_file_template/template.114255/wafer.1/imprint.1/TTMLogStream.1', '114255'),
    ('./trace_file_template/template.114256/wafer.1/imprint.1/TTMLogStream.1', '114256'),
    ('./trace_file_template/template.114257/wafer.1/imprint.1/TTMLogStream.1', '114257'),
    ('./trace_file_template/template.114258/wafer.1/imprint.1/TTMLogStream.1', '114258'),
    ('./trace_file_template/template.114259/wafer.1/imprint.1/TTMLogStream.1', '114259'),
    ('./trace_file_template/template.114260/wafer.1/imprint.1/TTMLogStream.1', '114260'),
    ('./trace_file_template/template.114261/wafer.1/imprint.1/TTMLogStream.1', '114261'),
    ('./trace_file_template/template.114262/wafer.1/imprint.1/TTMLogStream.1', '114262'),
    ('./trace_file_template/template.114263/wafer.1/imprint.1/TTMLogStream.1', '114263'),
    ('./trace_file_template/template.114264/wafer.1/imprint.1/TTMLogStream.1', '114264'),
    ('./trace_file_template/template.114265/wafer.1/imprint.1/TTMLogStream.1', '114265'),
    ('./trace_file_template/template.114266/wafer.1/imprint.1/TTMLogStream.1', '114266'),
    ('./trace_file_template/template.114267/wafer.1/imprint.1/TTMLogStream.1', '114267'),
    ('./trace_file_template/template.114268/wafer.1/imprint.1/TTMLogStream.1', '114268'),
    ('./trace_file_template/template.114269/wafer.1/imprint.1/TTMLogStream.1', '114269'),
    ('./trace_file_template/template.114270/wafer.1/imprint.1/TTMLogStream.1', '114270'),
    ('./trace_file_template/template.114271/wafer.1/imprint.1/TTMLogStream.1', '114271'),
    ('./trace_file_template/template.114272/wafer.1/imprint.1/TTMLogStream.1', '114272'),
    ('./trace_file_template/template.114273/wafer.1/imprint.1/TTMLogStream.1', '114273'),
    ('./trace_file_template/template.114274/wafer.1/imprint.1/TTMLogStream.1', '114274'),
    ('./trace_file_template/template.114275/wafer.1/imprint.1/TTMLogStream.1', '114275'),
    ('./trace_file_template/template.114276/wafer.1/imprint.1/TTMLogStream.1', '114276'),
    ('./trace_file_template/template.114277/wafer.1/imprint.1/TTMLogStream.1', '114277'),
    ('./trace_file_template/template.114278/wafer.1/imprint.1/TTMLogStream.1', '114278'),
    ('./trace_file_template/template.114279/wafer.1/imprint.1/TTMLogStream.1', '114279'),
    ('./trace_file_template/template.114280/wafer.1/imprint.1/TTMLogStream.1', '114280'),
    ('./trace_file_template/template.114281/wafer.1/imprint.1/TTMLogStream.1', '114281'),
    ('./trace_file_template/template.114282/wafer.1/imprint.1/TTMLogStream.1', '114282'),
    ('./trace_file_template/template.114283/wafer.1/imprint.1/TTMLogStream.1', '114283'),
    ('./trace_file_template/template.114284/wafer.1/imprint.1/TTMLogStream.1', '114284'),
    ('./trace_file_template/template.114285/wafer.1/imprint.1/TTMLogStream.1', '114285'),
    ('./trace_file_template/template.114286/wafer.1/imprint.1/TTMLogStream.1', '114286'),
    ('./trace_file_template/template.114287/wafer.1/imprint.1/TTMLogStream.1', '114287'),
    ('./trace_file_template/template.114288/wafer.1/imprint.1/TTMLogStream.1', '114288'),
    ('./trace_file_template/template.114289/wafer.1/imprint.1/TTMLogStream.1', '114289'),
    ('./trace_file_template/template.114290/wafer.1/imprint.1/TTMLogStream.1', '114290'),
    ('./trace_file_template/template.114291/wafer.1/imprint.1/TTMLogStream.1', '114291'),
    ('./trace_file_template/template.114292/wafer.1/imprint.1/TTMLogStream.1', '114292'),
    ('./trace_file_template/template.114293/wafer.1/imprint.1/TTMLogStream.1', '114293'),
    ('./trace_file_template/template.114294/wafer.1/imprint.1/TTMLogStream.1', '114294'),
    ('./trace_file_template/template.114295/wafer.1/imprint.1/TTMLogStream.1', '114295'),
    ('./trace_file_template/template.114296/wafer.1/imprint.1/TTMLogStream.1', '114296'),
    ('./trace_file_template/template.114297/wafer.1/imprint.1/TTMLogStream.1', '114297'),
    ('./trace_file_template/template.114298/wafer.1/imprint.1/TTMLogStream.1', '114298')
]
print("num files: ", len(trace_file_lst))
# Out:
# num files:  92

# %%
TTMStream_data = {}
base_path = '%s/TTM_Vibration/trace_file_template' % (paths.tmp_dir)
wafer_id = 1
imprint_id = 1

for name in glob.glob('%s/template.*' % (base_path)):
    template_id = int(name[name.rfind('.')+1:])
    TTMLogStream_path = '%s/wafer.%d/imprint.%d/TTMLogStream.1' % (name, wafer_id, imprint_id)    
    data19_path = '%s/wafer.%d/imprint.%d/data19.1' % (name, wafer_id, imprint_id)    
    with open(data19_path, 'rb') as data19_file:
        data19_file.seek(3*128)
        x_mm = np.frombuffer(data19_file.read(8), dtype=np.float64)[0]
        y_mm = np.frombuffer(data19_file.read(8), dtype=np.float64)[0]
    print( (TTMLogStream_path, template_id, (x_mm, y_mm)) )
    TTMStream_data[template_id] = (TTMLogStream_path, (x_mm, y_mm))

print("num files: ", len(TTMStream_data))
# Out:
# ('/Users/trafferty/tmp/TTM_Vibration/trace_file_template/template.114207/wafer.1/imprint.1/TTMLogStream.1', 114207, (43.829999999999998, -62.859999999999999))
# ('/Users/trafferty/tmp/TTM_Vibration/trace_file_template/template.114208/wafer.1/imprint.1/TTMLogStream.1', 114208, (19.48, -62.859999999999999))
# ('/Users/trafferty/tmp/TTM_Vibration/trace_file_template/template.114209/wafer.1/imprint.1/TTMLogStream.1', 114209, (-4.8700000000000001, -62.859999999999999))
# ('/Users/trafferty/tmp/TTM_Vibration/trace_file_template/template.114210/wafer.1/imprint.1/TTMLogStream.1', 114210, (-29.219999999999999, -62.859999999999999))
# ('/Users/trafferty/tmp/TTM_Vibration/trace_file_template/template.114211/wafer.1/imprint.1/TTMLogStream.1', 114211, (-53.57, -62.859999999999999))
# ('/Users/trafferty/tmp/TTM_Vibration/trace_file_template/template.114212/wafer.1/imprint.1/TTMLogStream.1', 114212, (68.180000000000007, -31.43))
# ...

# %%
#TTMLogStream_path= '%s/TTM_Vibration/%s' % (paths.tmp_dir, trace_file_lst[0]
                                            
                                            
def read_ttm_raw(TTMLogStream_path):
    # new way (UDP):
    legacy, fname = False, TTMLogStream_path

    ## old way (TCP)
    #legacy, fname = True, '%s/TTMLogStream_TEST.csv' % (tmp_dir)

    f = open(fname, 'r')
    ttm = f.readlines()
    f.close()
    if debug: print("Unfiltered len:", len(ttm))

    ttm[:] = [element for element in ttm if TTMUtil.include_element(element)]

    if debug: print("Filtered len  :", len(ttm))
    return ttm

# %%
id_to_pos = {}
id_to_pos[114207] = (43.83  ,     -62.86   )
id_to_pos[114208] = (19.48  ,     -62.86   )
id_to_pos[114209] = (-4.87  ,     -62.86   )
id_to_pos[114210] = (-29.22 ,      -62.86  )
id_to_pos[114211] = (-53.57 ,      -62.86  )
id_to_pos[114212] = (68.18  ,     -31.43   )
id_to_pos[114213] = (43.83  ,     -31.43   )
id_to_pos[114214] = (19.48  ,     -31.43   )
id_to_pos[114215] = (-4.87  ,     -31.43   )
id_to_pos[114216] = (-29.22 ,      -31.43  )
id_to_pos[114217] = (-53.57 ,      -31.43  )
id_to_pos[114218] = (-77.92 ,      -31.43  )
id_to_pos[114219] = (68.18  ,          0   )
id_to_pos[114220] = (43.83  ,          0   )
id_to_pos[114221] = (19.48  ,          0   )
id_to_pos[114222] = (-4.87  ,         0    )
id_to_pos[114223] = (-29.22 ,           0  )
id_to_pos[114224] = (-53.57 ,           0  )
id_to_pos[114225] = (-77.92 ,           0  )
id_to_pos[114226] = (68.18  ,      31.43   )
id_to_pos[114227] = (43.83  ,      31.43   )
id_to_pos[114228] = (19.48  ,      31.43   )
id_to_pos[114229] = (-4.87  ,      31.43   )
id_to_pos[114230] = (-29.22 ,       31.43  )
id_to_pos[114231] = (-53.57 ,       31.43  )
id_to_pos[114232] = (-77.92 ,       31.43  )
id_to_pos[114233] = (43.83  ,      62.86   )
id_to_pos[114234] = (19.48  ,      62.86   )
id_to_pos[114235] = (-4.87  ,      62.86   )
id_to_pos[114236] = (-29.22 ,       62.86  )
id_to_pos[114237] = (-53.57 ,       62.86  )
id_to_pos[114238] = (68.18  ,     -125.72  )
id_to_pos[114239] = (68.18  ,     -94.29   )
id_to_pos[114240] = (43.83  ,     -125.72  )
id_to_pos[114241] = (43.83  ,     -94.29   )
id_to_pos[114242] = (-29.22 ,      -125.72 )
id_to_pos[114243] = (-29.22 ,      -94.29  )
id_to_pos[114244] = (-53.57 ,      -125.72 )
id_to_pos[114245] = (-53.57 ,      -94.29  )
id_to_pos[114246] = (-77.92 ,      -125.72 )
id_to_pos[114247] = (-77.92 ,      -94.29  )
id_to_pos[114248] = (-102.27,        -94.29)
id_to_pos[114249] = (-102.27,        -62.86)
id_to_pos[114250] = (116.88 ,       -94.29 )
id_to_pos[114251] = (92.53  ,     -62.86   )
id_to_pos[114252] = (92.53  ,     -94.29   )
id_to_pos[114253] = (68.18  ,     -62.86   )
id_to_pos[114254] = (-126.62,        -62.86)
id_to_pos[114255] = (-126.62,        -31.43)
id_to_pos[114256] = (116.88 ,       -62.86 )
id_to_pos[114257] = (92.53  ,     -31.43   )
id_to_pos[114258] = (141.23 ,       -31.43 )
id_to_pos[114259] = (116.88 ,       -31.43 )
id_to_pos[114260] = (141.23 ,            0 )
id_to_pos[114261] = (116.88 ,            0 )
id_to_pos[114262] = (141.23 ,        31.43 )
id_to_pos[114263] = (116.88 ,        31.43 )
id_to_pos[114264] = (116.88 ,        62.86 )
id_to_pos[114265] = (92.53  ,      62.86   )
id_to_pos[114266] = (-126.62,         62.86)
id_to_pos[114267] = (-102.27,         62.86)
id_to_pos[114268] = (116.88 ,        94.29 )
id_to_pos[114269] = (68.18  ,      62.86   )
id_to_pos[114270] = (92.53  ,      94.29   )
id_to_pos[114271] = (68.18  ,      94.29   )
id_to_pos[114272] = (-102.27,         94.29)
id_to_pos[114273] = (-77.92 ,       94.29  )
id_to_pos[114274] = (68.18  ,      125.72  )
id_to_pos[114275] = (43.83  ,      94.29   )
id_to_pos[114276] = (43.83  ,      125.72  )
id_to_pos[114277] = (19.48  ,      94.29   )
id_to_pos[114278] = (-29.22 ,       125.72 )
id_to_pos[114279] = (-4.87  ,      94.29   )
id_to_pos[114280] = (-53.57 ,       125.72 )
id_to_pos[114281] = (-53.57 ,       94.29  )
id_to_pos[114282] = (-77.92 ,       125.72 )
id_to_pos[114283] = (-77.92 ,       62.86  )
id_to_pos[114284] = (19.48  ,     -125.72  )
id_to_pos[114285] = (-4.87  ,     -125.72  )
id_to_pos[114286] = (19.48  ,     -94.29   )
id_to_pos[114287] = (-4.87  ,     -94.29   )
id_to_pos[114288] = (-77.92 ,      -62.86  )
id_to_pos[114289] = (-102.27,        -31.43)
id_to_pos[114290] = (92.53  ,          0   )
id_to_pos[114291] = (-102.27,             0)
id_to_pos[114292] = (-126.62,             0)
id_to_pos[114293] = (92.53  ,      31.43   )
id_to_pos[114294] = (-102.27,         31.43)
id_to_pos[114295] = (-126.62,         31.43)
id_to_pos[114296] = (-29.22 ,       94.29  )
id_to_pos[114297] = (19.48  ,      125.72  )
id_to_pos[114298] = (-4.87  ,      125.72  )
print("num IDs: ", len(id_to_pos))



fig = plt.figure(figsize=(18,18))
fig.suptitle('Imprint Loc by Template ID', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
#fig.subplots_adjust(top=0.85)
# ax.set_title('axes title')

# ax.set_xlabel('xlabel')
# ax.set_ylabel('ylabel')

for k,v in id_to_pos.items():
    #print("%d: [%f, %f]" % (k, v[0], v[1]) )
    tt = "%s\n0:100%%\n1:70%%\n2:70%%\n3:70%%\n4:70%%" % k
    ax.text(int(v[0])-5, int(v[1])-10, tt, fontsize=9)

# ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)

# ax.text(3, 2, u'unicode: Institut f\374r Festk\366rperphysik')

# ax.text(0.95, 0.01, 'colored text in axes coords',
#         verticalalignment='bottom', horizontalalignment='right',
#         transform=ax.transAxes,
#         color='green', fontsize=15)


# ax.plot([2], [1], 'o')
# ax.annotate('annotate', xy=(2, 1), xytext=(3, 4),
#             arrowprops=dict(facecolor='black', shrink=0.05))

pitch_y = 30
offset_y = 16
pitch_x = 24
offset_x = 13
for i in range(5):
    plt.axhline(offset_y+(i*pitch_y), color='gray')
for i in range(5):
    plt.axhline(-offset_y-(i*pitch_y), color='gray')
for i in range(7):
    plt.axvline(offset_x+(i*pitch_x), color='gray')
for i in range(6):
    plt.axvline(-offset_x-(i*pitch_x), color='gray')

ax.axis([-160, 160, -160, 160])

plt.show()
# Out:
# num IDs:  92

# %%
wafer_data_sets = OrderedDict()

for template_id, d in TTMStream_data.items():    
    TTMLogStream_path = d[0]
    field_pos = d[1]
    print("For template ID: ", template_id)
    
    # read in raw ttm data from template.xxxxx/wafer.x/imprint.x/TTMLogStream.1
    ttm = read_ttm_raw(TTMLogStream_path)

    # parse into data sets (rough)
    data_ranges, data_sets_rough = TTMUtil.parse_into_data_sets(ttm)

    # cleanup rough data sets and create data_sets list (data_set=all trace data from single imprint, should be 67 colums of data)
    data_sets = []
    for idx, data_set in enumerate(data_sets_rough):
        data_sets.append(TTMUtil.cleanup_and_format_data_set(data_set, legacy))

    wafer_data_sets[template_id] = data_sets[0]

print("len(wafer_data_sets):", len(wafer_data_sets))
# Out:
# For template ID:  114207
# Data set 0, range: 0 - 3807 (total: 3807)
# [0] range: doTTMClientWork: 2017-10-11 17:34:50.145 -> doTTMClientWork: 2017-10-11 17:34:54.144
# For template ID:  114208
# Data set 0, range: 0 - 8564 (total: 8564)
# [0] range: doTTMClientWork: 2017-10-11 17:34:58.762 -> doTTMClientWork: 2017-10-11 17:35:07.760
# For template ID:  114209
# Data set 0, range: 0 - 952 (total: 952)
# [0] range: doTTMClientWork: 2017-10-11 17:35:12.340 -> doTTMClientWork: 2017-10-11 17:35:13.338
# For template ID:  114210
# Data set 0, range: 0 - 8561 (total: 8561)
# [0] range: doTTMClientWork: 2017-10-11 17:35:22.138 -> doTTMClientWork: 2017-10-11 17:35:31.156
# For template ID:  114211
# Data set 0, range: 0 - 951 (total: 951)
# [0] range: doTTMClientWork: 2017-10-11 17:35:35.613 -> doTTMClientWork: 2017-10-11 17:35:36.612
# For template ID:  114212
# Data set 0, range: 0 - 8564 (total: 8564)
# ...

# %%
import math
def data_set_metrics(data_set):
    validx = {0:0, 1:0, 2:0, 3:0, 4:0}
    validy = {0:0, 1:0, 2:0, 3:0, 4:0}
    validx_records = []
    validy_records = []
    for d in data_set:
        x = 4-(d[col_ids['C0 cscorex']] + d[col_ids['C1 cscorex']] + d[col_ids['C2 cscorex']] + d[col_ids['C3 cscorex']])
        validx[x] += 1

        y = 4-(d[col_ids['C0 cscorey']] + d[col_ids['C1 cscorey']] + d[col_ids['C2 cscorey']] + d[col_ids['C3 cscorey']])
        validy[y] += 1

    df = pd.DataFrame.from_records(data_set, columns=cols)
    df_c0x = df['C0 post measx_mm']
    df_c0y = df['C0 post measy_mm']
    df_c1x = df['C1 post measx_mm']
    df_c1y = df['C1 post measy_mm']
    df_c2x = df['C2 post measx_mm']
    df_c2y = df['C2 post measy_mm']
    df_c3x = df['C3 post measx_mm']
    df_c3y = df['C3 post measy_mm']

    #     if d[col_ids['C0 cscorex']] == 0: validx_cnt += 1
    #     if d[col_ids['C1 cscorex']] == 0: validx_cnt += 1
    #     if d[col_ids['C2 cscorex']] == 0: validx_cnt += 1
    #     if d[col_ids['C3 cscorex']] == 0: validx_cnt += 1
    #     if d[col_ids['C0 cscorey']] == 0: validy_cnt += 1
    #     if d[col_ids['C1 cscorey']] == 0: validy_cnt += 1
    #     if d[col_ids['C2 cscorey']] == 0: validy_cnt += 1
    #     if d[col_ids['C3 cscorey']] == 0: validy_cnt += 1
    
    total = len(data_set)
    per_of_total = []
    print("Distribution of valid TTM signals: ")
    for idx in range(5):
        print("  %d valid TTM data pts: %.2f" %  (idx, ((validx[idx] / float(total)) * 100)) )
        
        
#         per_of_total.append(int(float(validx[idx] / total) * 100) )
#         #print("Percent valid TTM signals: %d:%f" % (idx, float(validx[idx] / total)) )
    
    
    
#     print("valid x cnts:", validx)
#     print("Distribution of valid TTM signals: ")
#     print("  Zero TTMs valid: %d%%, One TTMs valid: %d%%, Two TTMs valid: %d%%, Three TTMs valid: %d%%, Four TTMs valid: %d%%" % (
#           per_of_total[0]*100,
#           per_of_total[1]*100,
#           per_of_total[2]*100,
#           per_of_total[3]*100,
#           per_of_total[4]*100) )
    
    
#     print("Cam 1 X min: %+f, max: %+f, mean: %+f, std: %f" % (df_c0x.min(), df_c0x.max(), df_c0x.mean(),df_c0x.std()))
#     print("Cam 1 Y min: %+f, max: %+f, mean: %+f, std: %f" % (df_c0y.min(), df_c0y.max(), df_c0y.mean(),df_c0y.std()))
#     print("Cam 2 X min: %+f, max: %+f, mean: %+f, std: %f" % (df_c1x.min(), df_c1x.max(), df_c1x.mean(),df_c1x.std()))
#     print("Cam 2 Y min: %+f, max: %+f, mean: %+f, std: %f" % (df_c1y.min(), df_c1y.max(), df_c1y.mean(),df_c1y.std()))
#     print("Cam 3 X min: %+f, max: %+f, mean: %+f, std: %f" % (df_c2x.min(), df_c2x.max(), df_c2x.mean(),df_c2x.std()))
#     print("Cam 3 Y min: %+f, max: %+f, mean: %+f, std: %f" % (df_c2y.min(), df_c2y.max(), df_c2y.mean(),df_c2y.std()))
#     print("Cam 4 X min: %+f, max: %+f, mean: %+f, std: %f" % (df_c3x.min(), df_c3x.max(), df_c3x.mean(),df_c3x.std()))
#     print("Cam 4 Y min: %+f, max: %+f, mean: %+f, std: %f" % (df_c3y.min(), df_c3y.max(), df_c3y.mean(),df_c3y.std()))
    print("-------------------------------------------------")

    return validx

# %%
validx_by_template_id = {}
if 1:
    for template_id, data_set in wafer_data_sets.items():
        print("For template ID %d, pos [%.3f, %.3f]" %(template_id, id_to_pos[template_id][0], id_to_pos[template_id][0]))
        validx_by_template_id[template_id] = data_set_metrics(data_set)
else:
    template_id = 114213
    print("For template ID %d, pos: [%.3f, %.3f]" %(template_id, id_to_pos[template_id][0], id_to_pos[template_id][0]))
    validx = data_set_metrics(wafer_data_sets[template_id])
print(validx)
# Out:
# For template ID 114207, pos [43.830, 43.830]
# Distribution of valid TTM signals:
#   0 valid TTM data pts: 0.00
#   1 valid TTM data pts: 0.00
#   2 valid TTM data pts: 0.00
#   3 valid TTM data pts: 0.16
#   4 valid TTM data pts: 99.84
# -------------------------------------------------
# For template ID 114208, pos [19.480, 19.480]
# Distribution of valid TTM signals:
#   0 valid TTM data pts: 0.00
#   1 valid TTM data pts: 0.00
#   2 valid TTM data pts: 0.00
#   3 valid TTM data pts: 0.00
#   4 valid TTM data pts: 100.00
# -------------------------------------------------
# For template ID 114209, pos [-4.870, -4.870]
# Distribution of valid TTM signals:
#   0 valid TTM data pts: 0.00
#   1 valid TTM data pts: 0.00
#   2 valid TTM data pts: 0.00
#   3 valid TTM data pts: 0.21
#   4 valid TTM data pts: 99.79
# -------------------------------------------------
# For template ID 114210, pos [-29.220, -29.220]
# Distribution of valid TTM signals:
#   0 valid TTM data pts: 0.00
# ...

# %%
plot_file_pdf = "%s/TTM_signals_per_field.pdf" % (paths.tmp_dir)
from matplotlib.backends.backend_pdf import PdfPages
pdf = PdfPages(plot_file_pdf)
# set the file's metadata via the PdfPages object:
d = pdf.infodict() 
d['Title'] = "TTM_signals_per_field"
d['Author'] = 'Tom Rafferty'
d['Subject'] = 'TTM CanonLan Interface Analysis'
d['CreationDate'] = datetime.datetime.today()
d['ModDate'] = datetime.datetime.today()


fig = plt.figure(figsize=(18,18))
fig.suptitle('Imprint Loc by Template ID', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)

for template_id, d in TTMStream_data.items():    
    field_pos = d[1]
    
    validx = validx_by_template_id[template_id]
    total = 0
    for idx in range(5):
        total += validx[idx]
    
    #print("%d: [%f, %f]" % (k, v[0], v[1]) )
    tt = "%s\n" % (template_id) 
    for idx in range(5):
        tt += " %d: %.2f\n" % (idx, ((validx[idx] / float(total)) * 100))
    #tt = "%s\n0:100%%\n1:70%%\n2:70%%\n3:70%%\n4:70%%" % k
    ax.text(int(field_pos[0])-5, int(field_pos[1])-10, tt, fontsize=9)

pitch_y = 31
offset_y = 16
pitch_x = 24
offset_x = 13
for i in range(5):
    plt.axhline(offset_y+(i*pitch_y), color='gray')
for i in range(5):
    plt.axhline(-offset_y-(i*pitch_y), color='gray')
for i in range(7):
    plt.axvline(offset_x+(i*pitch_x), color='gray')
for i in range(6):
    plt.axvline(-offset_x-(i*pitch_x), color='gray')

ax.axis([-160, 160, -160, 160])

plt.show()

fig.savefig(pdf, format='pdf')
pdf.close()

# %%
def plot_series(df, title_str, query_str, save_pdf):
    df_sub = df.query(query_str)
    
    df_labels = [
        ('Cam 0 - X', 'C0 post measx_mm', 'C0 cmeasx_mm','C0 measx_mm','C0 scorex','C0 cscorex'),
        ('Cam 0 - Y', 'C0 post measy_mm', 'C0 cmeasy_mm','C0 measy_mm','C0 scorey','C0 cscorey'),
        ('Cam 1 - X', 'C1 post measx_mm', 'C1 cmeasx_mm','C1 measx_mm','C1 scorex','C1 cscorex'),
        ('Cam 1 - Y', 'C1 post measy_mm', 'C1 cmeasy_mm','C1 measy_mm','C1 scorey','C1 cscorey'),
        ('Cam 2 - X', 'C2 post measx_mm', 'C2 cmeasx_mm','C2 measx_mm','C2 scorex','C2 cscorex'),
        ('Cam 2 - Y', 'C2 post measy_mm', 'C2 cmeasy_mm','C2 measy_mm','C2 scorey','C2 cscorey'),
        ('Cam 3 - X', 'C3 post measx_mm', 'C3 cmeasx_mm','C3 measx_mm','C3 scorex','C3 cscorex'),
        ('Cam 3 - Y', 'C3 post measy_mm', 'C3 cmeasy_mm','C3 measy_mm','C3 scorey','C3 cscorey')
    ]

    if save_pdf:
        plot_file_pdf = "%s/%s.pdf" % (paths.tmp_dir, title_str)
        from matplotlib.backends.backend_pdf import PdfPages
        pdf = PdfPages(plot_file_pdf)
        # set the file's metadata via the PdfPages object:
        d = pdf.infodict() 
        d['Title'] = title_str
        d['Author'] = 'Tom Rafferty'
        d['Subject'] = 'TTM CanonLan Interface Analysis'
        d['CreationDate'] = datetime.datetime.today()
        d['ModDate'] = datetime.datetime.today()
        
        # setup vars to control page layout
        num_plots = len(df_labels)
        plots_per_page = num_plots
        num_pages = np.ceil(num_plots / plots_per_page)
        nb_pages = int(np.ceil(num_plots / float(plots_per_page)))
        grid_size = (plots_per_page, 1)

        print("Creating PDF (%s) with %d pages." % (plot_file_pdf, num_pages))
        print("Total plots: %d, plots per page: %d" % (num_plots, plots_per_page))
    
    #fig = plt.figure(figsize=(18,3))
    fig, axes = plt.subplots(nrows=plots_per_page, ncols=1, squeeze=True, figsize=(18,(4*plots_per_page)))
    
    for label_num, df_label in enumerate(df_labels):
        time_s = df_sub['time_s']
        post_meas = df_sub[df_label[1]]
        cmeas = df_sub[df_label[2]]
        meas = df_sub[df_label[3]]
        score = (df_sub[df_label[4]] + df_sub[df_label[5]]) / 100

        print(" ...Plotting series %d of %d" % (label_num+1, num_plots))
    #     print(len(df_col))
    #     print(len(time_s))

        delta_s = [0]
        for idx, d in enumerate(time_s):
            if idx > 0:
                delta_s.append(abs(d - d_prev))
            d_prev = d
        
        #fig, ax1 = plt.subplots(figsize=(18,3))
        #plt.subplot(num_plots,1,label_num+1)
        #ax1 = plt.gca()        
        ax1 = axes[label_num]
        
        ax1.plot(time_s, cmeas,  color='b', label='coarse')
        ax1.plot(time_s, post_meas,  color='g', label='post_meas')
        ax1.set_xlabel('time (s)')
        # Make the y-axis label, ticks and tick labels match the line color.
        ax1.set_ylabel('cmeas, meas', color='b')
        ax1.tick_params('y', colors='b')
        ax1.set_title("%s - %s" % (title_str, df_label[0]))

        ax2 = ax1.twinx()
        ax2.plot(time_s, score,  color='m', label='score')
        ax2.plot(time_s, delta_s,  color='c', label='delta_s')
        ax2.set_ylabel('score, delta_s', color='m')
        ax2.tick_params('y', colors='m')

        leg1 = ax1.legend(loc='upper left', shadow=True)
        leg2 = ax2.legend(loc='upper right', shadow=True)
    
    plt.title(title_str)
    plt.tight_layout()
    plt.show()
                    
    if save_pdf:
#         for fig in figs:
#             fig.savefig(pdf, format='pdf')
        print("Saving pdf...")
        fig.savefig(pdf, format='pdf')
        pdf.close()

# %%
def plot_scores(df, title_str, query_str, save_pdf):
    df_sub = df.query(query_str)
    
    df_labels = [
        ('C0 scorex','C0 cscorex'),
        ('C0 scorey','C0 cscorey'),
        ('C1 scorex','C1 cscorex'),
        ('C1 scorey','C1 cscorey'),
        ('C2 scorex','C2 cscorex'),
        ('C2 scorey','C2 cscorey'),
        ('C3 scorex','C3 cscorex'),
        ('C3 scorey','C3 cscorey')
    ]

    if save_pdf:
        plot_file_pdf = "%s/%s_TTM_scores.pdf" % (paths.tmp_dir, title_str)
        from matplotlib.backends.backend_pdf import PdfPages
        pdf = PdfPages(plot_file_pdf)
        # set the file's metadata via the PdfPages object:
        d = pdf.infodict() 
        d['Title'] = title_str
        d['Author'] = 'Tom Rafferty'
        d['Subject'] = 'TTM CanonLan Interface Analysis'
        d['CreationDate'] = datetime.datetime.today()
        d['ModDate'] = datetime.datetime.today()
        
        # setup vars to control page layout
        num_plots = len(df_labels)
        plots_per_page = num_plots
        num_pages = np.ceil(num_plots / plots_per_page)
        nb_pages = int(np.ceil(num_plots / float(plots_per_page)))
        grid_size = (plots_per_page, 1)

        print("Creating PDF (%s) with %d pages." % (plot_file_pdf, num_pages))
        print("Total plots: %d, plots per page: %d" % (num_plots, plots_per_page))
    
    plt.close()
    
    #fig = plt.figure(figsize=(18,1))
    fig, axes = plt.subplots(nrows=plots_per_page, ncols=1, squeeze=True, figsize=(18, int((2*plots_per_page)*.7)))
    #plt.close(fig)
    
    for label_num, df_label in enumerate(df_labels):
        time_s = df_sub['time_s']
        score = (df_sub[df_label[0]] + df_sub[df_label[1]]) / 2
        #score = ( df_sub[df_label[1]])

        ax1 = axes[label_num]
        plt.cla()
        
        ax1.plot(time_s, score,  color='m', label='score')
        ax1.set_xlabel('time (s)')
        # Make the y-axis label, ticks and tick labels match the line color.
        ax1.set_ylabel('Score', color='m')
        ax1.tick_params('y', colors='b')
        ax1.set_title("%s - %s" % (title_str, df_label[0]))

        #leg1 = ax1.legend(loc='upper left', shadow=True)
        
        
        #plt.plot(time_s, score,  label=df_label[1])
    
    #plt.title(title_str)
    plt.tight_layout()
    plt.show()
                    
    if save_pdf:
#         for fig in figs:
#             fig.savefig(pdf, format='pdf')
        print("Saving pdf...")
        fig.savefig(pdf, format='pdf')
        pdf.close()

# %%
save_pdf = True
query_str = '1 <= time_s < 30'  # used to filter out data

if 1:
    for template_id, data_set in wafer_data_sets.items():
        df = pd.DataFrame.from_records(data_set, columns=cols)
        plot_scores(df, str(template_id), query_str, save_pdf )
#     data_set_metrics(v)
else:
    df = pd.DataFrame.from_records(wafer_data_sets['114213'], columns=cols)
    plot_scores(df, '114213', query_str, save_pdf )
# Out:
# Creating PDF (/Users/trafferty/tmp/114207_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114208_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114209_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114210_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114211_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114212_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114213_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# Saving pdf...
# Creating PDF (/Users/trafferty/tmp/114214_TTM_scores.pdf) with 1 pages.
# Total plots: 8, plots per page: 8
# ...

# %%
# 22: '20.1 <= time_s < 20.4'
# 26: '1 <= time_s < 3'

vib_sets_05_17 = [(22, '30271', '18.1 <= time_s < 22.4'),
            (22, '30271_long', '1 <= time_s < 30'),
            (26, '30279', '1 <= time_s < 3'),
            (26, '30279_before', '1.3 <= time_s < 1.75')]

vib_sets_05_24 = [(0, '30380', '0 <= time_s < 30'),
            (1, '30382', '0 <= time_s < 30'),
            (2, '30384', '0 <= time_s < 30'),
            (3, '30385', '0 <= time_s < 30'),
            (4, '30386', '0 <= time_s < 30')]

#vib_sets = [(5, '30105', '0 <= time_s < 32')]

vib_sets = vib_sets_05_17
i = 0
save_pdf = True

df = pd.DataFrame.from_records(data_sets[vib_sets[i][0]], columns=cols)

for i in range(len(vib_sets)):
    df = pd.DataFrame.from_records(data_sets[vib_sets[i][0]], columns=cols)
    plot_series(df, vib_sets[i][1], vib_sets[i][2], save_pdf )

plot_series(df, vib_sets[i][1], vib_sets[i][2], save_pdf )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-11d6d839308f> in <module>()
#      19 save_pdf = True
#      20
# ---> 21 df = pd.DataFrame.from_records(data_sets[vib_sets[i][0]], columns=cols)
#      22
#      23 for i in range(len(vib_sets)):
#
# IndexError: list index out of range

# %%
df = pd.DataFrame.from_records(data_sets[26], columns=cols)
df_sub = df.query('1.415 <= time_s < 1.735')
#df.describe()

time_s = df_sub['time_s']
df_c0x = df_sub['C0 measx_mm']
df_c0y = df_sub['C0 measy_mm']
df_c1x = df_sub['C1 measx_mm']
df_c1y = df_sub['C1 measy_mm']
df_c2x = df_sub['C2 measx_mm']
df_c2y = df_sub['C2 measy_mm']
df_c3x = df_sub['C3 measx_mm']
df_c3y = df_sub['C3 measy_mm']

print("num pts:", len(df_c0x))

fig, ax1 = plt.subplots(figsize=(18,3))
ax1.plot(time_s, df_c0x,  color='b', label='coarse')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('cmeas, meas', color='b')
ax1.tick_params('y', colors='b')
plt.show()
time_s
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-11248d61082d> in <module>()
# ----> 1 df = pd.DataFrame.from_records(data_sets[26], columns=cols)
#       2 df_sub = df.query('1.415 <= time_s < 1.735')
#       3 #df.describe()
#       4
#       5 time_s = df_sub['time_s']
#
# IndexError: list index out of range

# %%
plt.figure(figsize=(20,2))
plt.plot(df['C0 post measx_mm'], color='r')
plt.plot(df['C0 post measy_mm'], color='b')
plt.figure(figsize=(20,2))
plt.plot(df['C1 post measx_mm'], color='r')
plt.plot(df['C1 post measy_mm'], color='b')
plt.figure(figsize=(20,2))
plt.plot(df['C2 post measx_mm'], color='r')
plt.plot(df['C2 post measy_mm'], color='b')
plt.figure(figsize=(20,2))
plt.plot(df['C3 post measx_mm'], color='r')
plt.plot(df['C3 post measy_mm'], color='b')
# plt.vlines(rt_peakIdx, 0, np.max(patch_diff) + 25, color='r')
#plt.title('TTM Data')

# %%
plt.figure(figsize=(20,2))
plt.plot(df['C0 measx_mm'], color='r')
plt.plot(df['C0 measy_mm'], color='b')
plt.figure(figsize=(20,2))
plt.plot(df['C1 measx_mm'], color='r')
plt.plot(df['C1 measy_mm'], color='b')
plt.figure(figsize=(20,2))
plt.plot(df['C2 measx_mm'], color='r')
plt.plot(df['C2 measy_mm'], color='b')
plt.figure(figsize=(20,2))
plt.plot(df['C3 measx_mm'], color='r')
plt.plot(df['C3 measy_mm'], color='b')

# %%
df = pd.DataFrame.from_records(ds, columns=cols)
#df.describe()
df['Cam3_TimeStamp']
# Out:
# 0       127049
# 1       129649
# 2       132249
# 3       134849
# 4       137449
# 5       140041
# 6       142641
# 7       145241
# 8       147841
# 9       150441
# 10      153041
# 11      155641
# 12      158241
# 13      160841
# 14      163441
# 15      166034
# 16      168634
# 17      171234
# 18      173834
# 19      176434
# 20      179034
# 21      181634
# 22      184234
# 23      186834
# 24      189434
# 25      192026
# 26      194626
# 27      197226
# 28      199826
# 29      202426
#          ...
# 3621    538936
# 3622    541536
# 3623    544128
# 3624    546728
# 3625    549328
# 3626    551928
# 3627    554528
# 3628    557128
# 3629    559728
# 3630    562328
# 3631    564928
# 3632    567528
# 3633    570120
# 3634    572720
# 3635    575320
# 3636    577920
# 3637    580520
# 3638    583120
# 3639    585720
# 3640    588320
# 3641    590920
# 3642    593520
# 3643    596113
# 3644    598713
# 3645    601313
# 3646    603913
# 3647    606513
# ...

# %%
df = pd.DataFrame.from_records(ds, columns=cols)
#df.describe()

cols_to_plot = ['Cam1_TimeStamp', 'Cam2_TimeStamp', 'Cam3_TimeStamp', 'Cam4_TimeStamp']
plt.figure(figsize=(30,20))

for col in cols_to_plot:
    print("%s" % col)
    cam_ts_deltas = []
    offset = 0
    for idx, ts in enumerate(df[col]):
        if idx > 0:
            if ts_prev == ts:
                delta = ts - ts_prev
                print("  delta at %d is %d (ts: %d, ts_prev: %d)" % (idx, delta, ts, ts_prev))
            elif ts_prev < ts:
                delta = ts - ts_prev
            else:
                delta = (1e6 - ts_prev) + ts

            cam_ts_deltas.append(delta)

        ts_prev = ts

    plt.plot(cam_ts_deltas)

    cam_ts_deltas_np = np.array(cam_ts_deltas)
    print(" Mean: %f" % cam_ts_deltas_np.mean())
    print(" Std : %f" % cam_ts_deltas_np.std())
    print(" Max : %f" % cam_ts_deltas_np.max())
    print(" Min : %f" % cam_ts_deltas_np.min())
# Out:
# Cam1_TimeStamp
#  Mean: 2599.250411
#  Std : 2.265351
#  Max : 2601.000000
#  Min : 2592.000000
# Cam2_TimeStamp
#  Mean: 2599.250411
#  Std : 2.265109
#  Max : 2601.000000
#  Min : 2592.000000
# Cam3_TimeStamp
#   delta at 50 is 0 (ts: 257011, ts_prev: 257011)
#   delta at 243 is 0 (ts: 758667, ts_prev: 758667)
#   delta at 436 is 0 (ts: 260324, ts_prev: 260324)
#   delta at 629 is 0 (ts: 761980, ts_prev: 761980)
#   delta at 791 is 0 (ts: 183052, ts_prev: 183052)
#   delta at 822 is 0 (ts: 263629, ts_prev: 263629)
#   delta at 1015 is 0 (ts: 765286, ts_prev: 765286)
#   delta at 1208 is 0 (ts: 266942, ts_prev: 266942)
#   delta at 1401 is 0 (ts: 768598, ts_prev: 768598)
#   delta at 1594 is 0 (ts: 270255, ts_prev: 270255)
#   delta at 1787 is 0 (ts: 771911, ts_prev: 771911)
#   delta at 1980 is 0 (ts: 273560, ts_prev: 273560)
#   delta at 2173 is 0 (ts: 775216, ts_prev: 775216)
#   delta at 2366 is 0 (ts: 276873, ts_prev: 276873)
# ...
