# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import glob
import itertools
from collections import namedtuple
import time

import pandas_profiling
plt.rcParams["figure.figsize"] = (30,20)

import sys
from paths import Paths
paths = Paths()
sys.path.append(paths.scripts_root)
import util

# %load_ext autoreload
# %autoreload 2

# Display entire width of browser
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

paths.print_paths()
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Paths defined in paths module:
#  paths.data_root: /Users/trafferty/data
#  paths.notebook_root: /Users/trafferty/data/notebooks
#  paths.scripts_root: /Users/trafferty/data/scripts
#  paths.images_root: /Users/trafferty/data/images
#  paths.projects_root: /Users/trafferty/data/projects
#  paths.results_root: /Users/trafferty/data/results
#  paths.tmp_root: /Users/trafferty/data/tmp
#  paths.dat_root: /Users/trafferty/data/dat
#  paths.tmp_dir: /Users/trafferty/tmp
#  paths.ws_dir: /Users/trafferty/workspace
#  paths.mii_home: /Users/trafferty/dev
#  paths.inhouse: /Users/trafferty/dev/src/inhouse

# %% [markdown]
# #### Create dispenser type and objects for Xaar and Oce

# %%
Dispenser = namedtuple('Dispenser', 'type, num_rows, nozzles_per_row, total_nozzles')

dispXaar = Dispenser('Xaar', 2, 500, 1000)
dispOce = Dispenser('OCE', 4, 214, 856)

# %% [markdown]
# #### Select dispenser type to work with for this session

# %%
disp = dispOce
print(f"Dispenser type selected: {disp.type}.  Attributes:")
print(f" Num rows:      {disp.num_rows}")
print(f" Noz per row:   {disp.nozzles_per_row}")
print(f" Total nozzles: {disp.total_nozzles}")
# Out:
# Dispenser type selected: OCE.  Attributes:
#  Num rows:      4
#  Noz per row:   214
#  Total nozzles: 856

# %% [markdown]
# ### Setup path for result folder and glob all of the result file paths into list

# %%
result_root = paths.tmp_dir + '/DIF/results/new'
result_files = glob.glob("%s/full_results_[0-9].csv" % (result_root))
result_files
# Out:
# ['/Users/trafferty/tmp/DIF/results/new/full_results_1.csv',
#  '/Users/trafferty/tmp/DIF/results/new/full_results_2.csv',
#  '/Users/trafferty/tmp/DIF/results/new/full_results_3.csv']

# %% [markdown]
# ### Combine all of the result files into one

# %%
df_list = []
for i, f in enumerate(result_files):
    df_sub = pd.read_csv(f)
    df_sub.insert(0, 'Experiment Num', i+1)
    print(f"...read in {len(df_sub)} from {f}")
    df_list.append(df_sub)
df_full = pd.concat(df_list).reset_index(drop=True)
print(f"Total datapoints read: {len(df_full)}")
# Out:
# ...read in 1075 from /Users/trafferty/tmp/DIF/results/new/full_results_1.csv
# ...read in 715 from /Users/trafferty/tmp/DIF/results/new/full_results_2.csv
# ...read in 180 from /Users/trafferty/tmp/DIF/results/new/full_results_3.csv
# Total datapoints read: 1970

# %% [markdown]
# #### Fix header fields, which have leading space in it

# %%
df_full.columns = [field.strip() for field in df_full.columns]
df_full.columns
# Out:
# Index(['Experiment Num', 'LoopID', 'ImageFile', 'Pattern', 'Waveform',
#        'Voltage', 'Clock', 'PD_delay_us', 'Row', 'Nozzle', 'NOI', 'Phase',
#        'Column', 'Primary', 'Velocity', 'Vol_top', 'Vol_bot'],
#       dtype='object')

# %% [markdown]
# #### ...and also the columns with string data:

# %%
for col_name in df_full.columns:
    if df_full[col_name].dtype == 'O':
        print(f"Stripping column {col_name}, which is dtype 'O'")
        df_full[col_name] = df_full[col_name].str.strip()
# Out:
# Stripping column ImageFile, which is dtype 'O'
# Stripping column Pattern, which is dtype 'O'
# Stripping column Waveform, which is dtype 'O'
# Stripping column NOI, which is dtype 'O'
# Stripping column Phase, which is dtype 'O'
# Stripping column Primary, which is dtype 'O'
# Stripping column Velocity, which is dtype 'O'
# Stripping column Vol_top, which is dtype 'O'
# Stripping column Vol_bot, which is dtype 'O'

# %% [markdown]
# #### Now fix the Velocity, Vol_top and Vol_bot series (convert to float, replace 'n/a' with NaN)

# %%
for field in ['Velocity', 'Vol_top', 'Vol_bot']:
    df_full[field] = pd.to_numeric(df_full[field], errors='coerce')

# %% [markdown]
# #### Save combined results just for the hell of it...

# %%
df_full.to_csv("%s/full_results_combined.csv" % (result_root))

# %% [markdown]
# #### Create new column with mean volume

# %%
df_full['Vol_mean'] = (df_full['Vol_top'] + df_full['Vol_bot']) / 2.0

# %% [markdown]
# #### Define some functions to use for classifying results based on volume and velocity ranges

# %%
vel_desired_range = (4.0, 5.0)
vol_desired_range = (0.8, 1.0)

def calc_class_str(vol, vel):
    vol_in_range = True if vol >= vol_desired_range[0] and vol <= vol_desired_range[1] else False
    vel_in_range = True if vel >= vel_desired_range[0] and vel <= vel_desired_range[1] else False
    if vol_in_range and vel_in_range:
        return 'vel_vol_in_range'
    elif vol_in_range:
        return 'vol_in_range'
    elif vel_in_range:
        return 'vel_in_range'
    else:
        return 'out_of_range'
        
def calc_class(vol, vel):
    vol_in_range = True if vol >= vol_desired_range[0] and vol <= vol_desired_range[1] else False
    vel_in_range = True if vel >= vel_desired_range[0] and vel <= vel_desired_range[1] else False
    if vol_in_range and vel_in_range:
        return 4
    elif vol_in_range:
        return 2
    elif vel_in_range:
        return 1
    else:
        return 0

# %% [markdown]
# #### Now, execute these functions for all rows in dataframe, creating new columns for class:
#     vel_vol_in_range (4): Both velocity and volume in desired range
#     vol_in_range (2): Volume only in desired range
#     vel_in_range (1): Velocity only in desired range
#     out_of_range (0): Neither velocity or volume in desired range

# %%
df_full['class'] = np.vectorize(calc_class)(df_full['Vol_mean'], df_full['Velocity'])
df_full['class_label'] = np.vectorize(calc_class_str)(df_full['Vol_mean'], df_full['Velocity'])

# %%
df_full.head()
# Out:
#    Experiment Num  LoopID                                          ImageFile  \
# 0               1       1  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...
# 1               1       1  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...
# 2               1       1  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...
# 3               1       1  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...
# 4               1       1  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...
#
#                    Pattern                Waveform  Voltage  Clock  \
# 0  bmp/g4x8_A204_26x33.drp  dis_waveform_time2.csv        0      0
# 1  bmp/g4x8_A204_26x33.drp  dis_waveform_time2.csv        0      0
# 2  bmp/g4x8_A204_26x33.drp  dis_waveform_time2.csv        0      0
# 3  bmp/g4x8_A204_26x33.drp  dis_waveform_time2.csv        0      0
# 4  bmp/g4x8_A204_26x33.drp  dis_waveform_time2.csv        0      0
#
#    PD_delay_us  Row  Nozzle    NOI Phase  Column Primary  Velocity  Vol_top  \
# 0        159.0    1      28  False     C       4    True       NaN      NaN
# 1        159.0    1      29  False     A       3    True     4.935    0.975
# 2        159.0    1      30  False     B       2    True     4.889    0.852
# 3        159.0    1      31  False     C       1    True     4.558    0.933
# 4        159.0    1      32   True     A       0    True     4.865    1.013
#
#    Vol_bot  Vol_mean  class       class_label
# 0      NaN       NaN      0      out_of_range
# 1    1.000    0.9875      4  vel_vol_in_range
# 2    0.905    0.8785      4  vel_vol_in_range
# 3    0.952    0.9425      4  vel_vol_in_range
# 4    1.066    1.0395      1      vel_in_range

# %% [markdown]
# #### Create dataframe of just the rows with velocity and volumes in desired ranges

# %%
df_good = df_full.loc[df_full['class'] == 4, :]

# %% [markdown]
# #### Experimented a bit with using a dummies truth table, but didn't end up using it

# %%
features = ['class', 'class_label']
df_dummies = pd.get_dummies(df_full[features])
df_dummies.head()
# Out:
#    class  class_label_out_of_range  class_label_vel_in_range  \
# 0      0                         1                         0
# 1      4                         0                         0
# 2      4                         0                         0
# 3      4                         0                         0
# 4      1                         0                         1
#
#    class_label_vel_vol_in_range  class_label_vol_in_range
# 0                             0                         0
# 1                             1                         0
# 2                             1                         0
# 3                             1                         0
# 4                             0                         0

# %% [markdown]
# #### Plot data and colorize based on class column

# %%
ax = df_full.plot(x='Vol_mean', y='Velocity', kind = 'scatter', c ='class', colormap='viridis')
ax.set(xlabel="Mean Volume (pL)", ylabel="Velocity (m/s)")
# Out:
# [Text(0,0.5,'Velocity (m/s)'), Text(0.5,0,'Mean Volume (pL)')]

# %% [markdown]
# #### Create dataframe with just the rows with velocity and volumes in desired ranges

# %%
num_full         = len(df_full)
num_good         = len(df_good)
num_vel_only     = len(df_full.loc[df_full['class'] == 1, :])
num_vol_only     = len(df_full.loc[df_full['class'] == 2, :])
num_out_of_range = len(df_full.loc[df_full['class'] == 0, :])

print( " ---------- STATS ---------------")
print(f"   Num vel and vol in range: {num_good} ({((num_good/num_full)*100):.2f}%)")
print(f" Num velocity only in range: {num_vel_only} ({((num_vel_only/num_full)*100):.2f}%)")
print(f"   Num volume only in range: {num_vol_only} ({((num_vol_only/num_full)*100):.2f}%)")
print(f"           Num out of range: {num_out_of_range} ({((num_out_of_range/num_full)*100):.2f}%)")
# Out:
#  ---------- STATS ---------------
#    Num vel and vol in range: 678 (34.42%)
#  Num velocity only in range: 387 (19.64%)
#    Num volume only in range: 138 (7.01%)
#            Num out of range: 767 (38.93%)

# %%
df_good.plot(x='Vol_mean', y='Velocity', kind = 'scatter')

# %% [markdown]
# #### Save these in their own file...

# %%
df_good.to_csv("%s/full_results_within_range.csv" % (result_root))

# %% [markdown]
# #### Categorize columns into similar groups:
#     disp_settings: tunable settings specific to dispenser
#     nozzle_settings: which nozzle and type
#     image_settings: image-specific attributes

# %%
disp_settings = ['Pattern', 'Waveform', 'Voltage', 'Clock', 'PD_delay_us']
nozzle_settings = ['Row', 'Nozzle', 'Phase']
image_settings = ['NOI', 'Column', 'Primary']

# %% [markdown]
# #### Now, for each category, get list of unique values for that column, put in dict for later

# %%
disp_unique = {}
for disp_setting in disp_settings:
    disp_unique[disp_setting] = list(df_good[disp_setting].unique())
print(f"Unique dispenser settings:\n{disp_unique}")

nozzle_unique = {}
for nozzle_setting in nozzle_settings:
    nozzle_unique[nozzle_setting] = list(df_good[nozzle_setting].unique())
print(f"\nUnique nozzle settings:\n{nozzle_unique}")

image_unique = {}
for image_setting in image_settings:
    image_unique[image_setting] = list(df_good[image_setting].unique())
print(f"\nUnique image settings:\n{image_unique}")
# Out:
# Unique dispenser settings:
# {'Pattern': ['bmp/g4x8_A204_26x33.drp', 'bmp/g2x8_A204_26x33.drp', 'bmp/g6x8_A204_26x33.drp', 'bmp/g4x16_A204_26x33.drp', 'bmp/g4x4_AB_A204_26x33.drp', 'bmp/g4x2_all_A204_26x33.drp', 'bmp/kk_RowA_8x8s0.drp', 'bmp/kk_8x2s0.drp', 'bmp/kk_8x6s0.drp', 'bmp/5X12s1.drp', 'bmp/kk_10X12s0.drp'], 'Waveform': ['dis_waveform_time2.csv'], 'Voltage': [0], 'Clock': [0], 'PD_delay_us': [159.0, 185.0, 287.0]}
#
# Unique nozzle settings:
# {'Row': [1], 'Nozzle': [29, 30, 31, 36, 37, 39, 41, 42, 45, 46, 48, 49, 51, 53, 55, 56, 58, 60, 61, 62, 67, 68, 69, 72, 74, 76, 79, 82, 84, 85, 86, 88, 90, 91, 94, 95, 96, 101, 102, 105, 106, 107, 108, 111, 112, 114, 115, 116, 118, 119, 123, 124, 129, 130, 131, 132, 133, 134, 135, 140, 141, 142, 144, 149, 150, 151, 153, 155, 159, 160, 161, 165, 169, 170, 171, 173, 176, 180, 183, 190, 192, 193, 194, 195, 196, 199, 201, 35, 97, 137, 164, 177, 202, 43, 50, 64, 104, 148, 163, 167, 198, 44, 136, 154, 184, 63, 187, 125, 182, 188, 200, 38], 'Phase': ['A', 'B', 'C']}
#
# Unique image settings:
# {'NOI': ['False', 'True'], 'Column': [3, 2, 1, 0, 4], 'Primary': ['True']}

# %% [markdown]
# #### For the unique dispense setting values, create a list of all permutations of these settings

# %%
permuts = list(itertools.product(disp_unique['Pattern'], disp_unique['Waveform'], disp_unique['Voltage'], disp_unique['Clock'], disp_unique['PD_delay_us']))
print(f"Permutation count: {len(permuts)}")
# Out:
# Permutation count: 33

# %%
# sandbox
pat, wf, volt, clock, pd_delay = permuts[0]
print(f"{pat}, {wf}, {volt}, {clock}, {pd_delay}")
len(df_full['Nozzle'].unique())
# Out:
# bmp/g4x8_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0
# 175

# %%
# sandbox
#df_sub = df_full.loc[(df_full['Pattern'] == pat) & (df_full['Waveform'] == wf) & (df_full['Voltage'] == v) & (df_full['Clock'] == c) & (df_full['PD_delay_us'] == pd_delay) ]
#df_sub = df_full.loc[(df_full['Pattern'] == pat)  ]
#df_sub = df_full.loc[(df_full['Pattern'] == pat) & (df_full['Waveform'] == wf) ]
#df_sub = df_full.loc[(df_full['Pattern'] == pat) & (df_full['Waveform'] == wf) & (df_full['PD_delay_us'] == pd_delay) ]
df_sub = df_good.loc[(df_full['Pattern'] == pat) & (df_full['PD_delay_us'] == pd_delay) ]
len(df_sub)
np.var(df_sub['Vol_mean'].values)
# Out:
# 0.0025101257229683364

# %% [markdown]
# #### For each permutation of dispense settings:
# - calculate the variance of the volume and velocity for all nozzles using those settings.
# - calculate the 'score' for the settings: vel variance multiplied by volume variance (lowest score indicates the dispense settings with the lowest overall variance, therefore the best)
# - append (key, score) tuple to list of scores
#
# ##### ...then sort the list of scores by lowest first

# %%
vel_vol_scores = []
for i, permut in enumerate(permuts):
    pat, wf, volt, clock, pd_delay = permut
    key = f"{pat}:{wf}:{volt}:{clock}:{pd_delay}"
    df_sub = df_good.loc[(df_good['Pattern'] == pat) & (df_good['Waveform'] == wf) & (df_good['Voltage'] == volt) & (df_good['Clock'] == clock) & (df_good['PD_delay_us'] == pd_delay) ]
    if len(df_sub):
        vol_var = np.var(df_sub['Vol_mean'].values)
        vel_var = np.var(df_sub['Velocity'].values)
        score = vol_var * vel_var * 1000
        vel_vol_scores.append( (key, score) )
        #print(f"{key}, vol variance: {vol_var:.6f}, vel variance: {vel_var:.6f}, score: {score:.6f}")   
vel_vol_scores_sorted = sorted(vel_vol_scores, key=lambda tup: tup[1])
vel_vol_scores_sorted
# Out:
# [('bmp/kk_8x6s0.drp:dis_waveform_time2.csv:0:0:185.0', 0.07659612859297966),
#  ('bmp/kk_8x2s0.drp:dis_waveform_time2.csv:0:0:185.0', 0.10096204825481116),
#  ('bmp/g4x16_A204_26x33.drp:dis_waveform_time2.csv:0:0:159.0',
#   0.11633470820891383),
#  ('bmp/g4x4_AB_A204_26x33.drp:dis_waveform_time2.csv:0:0:159.0',
#   0.12180787380276933),
#  ('bmp/kk_RowA_8x8s0.drp:dis_waveform_time2.csv:0:0:185.0',
#   0.1244828144510174),
#  ('bmp/g4x2_all_A204_26x33.drp:dis_waveform_time2.csv:0:0:159.0',
#   0.13498072701837469),
#  ('bmp/g2x8_A204_26x33.drp:dis_waveform_time2.csv:0:0:159.0',
#   0.13859848048149712),
#  ('bmp/g6x8_A204_26x33.drp:dis_waveform_time2.csv:0:0:159.0',
#   0.15396203809217),
#  ('bmp/g4x8_A204_26x33.drp:dis_waveform_time2.csv:0:0:159.0',
#   0.15491219811388643),
#  ('bmp/kk_10X12s0.drp:dis_waveform_time2.csv:0:0:287.0', 0.17415048029146868),
#  ('bmp/5X12s1.drp:dis_waveform_time2.csv:0:0:185.0', 0.2112945117606721)]

# %%
vel_vol_scores = []
for i, permut in enumerate(permuts):
    pat, wf, volt, clock, pd_delay = permut
    _hash = f"{pat}:{wf}:{volt}:{clock}:{pd_delay}"
                    
    df_sub = df_good.loc[(df_good['Pattern'] == pat) & (df_good['Waveform'] == wf) & (df_good['Voltage'] == volt) & (df_good['Clock'] == clock) & (df_good['PD_delay_us'] == pd_delay) ]
    if len(df_sub):
        vol_var = np.var(df_sub['Vol_mean'].values)
        vel_var = np.var(df_sub['Velocity'].values)
        score = vol_var * vel_var * 1000        
        #vel_vol_scores.append( {"Score":score, "Pattern":pat, "Waveform":wf, "Voltage":volt, "Clock":clock, "PD_delay_us":pd_delay} )
        vel_vol_scores.append( {"Score":score, "Disp Params Hash":_hash, "Vol var":vol_var, "Vel var":vel_var, "PD_delay_us":pd_delay} )
        #print(f"{key}, vol variance: {vol_var:.6f}, vel variance: {vel_var:.6f}, score: {score:.6f}")

df_vel_vol_scores = pd.DataFrame(vel_vol_scores)
df_vel_vol_scores_sorted = df_vel_vol_scores.sort_values(by=['Score'], ascending=True)
df_vel_vol_scores_sorted = df_vel_vol_scores_sorted.reset_index(drop=True)
df_vel_vol_scores_sorted
# Out:
#                                      Disp Params Hash  PD_delay_us     Score  \
# 0   bmp/kk_8x6s0.drp:dis_waveform_time2.csv:0:0:185.0        185.0  0.076596
# 1   bmp/kk_8x2s0.drp:dis_waveform_time2.csv:0:0:185.0        185.0  0.100962
# 2   bmp/g4x16_A204_26x33.drp:dis_waveform_time2.cs...        159.0  0.116335
# 3   bmp/g4x4_AB_A204_26x33.drp:dis_waveform_time2....        159.0  0.121808
# 4   bmp/kk_RowA_8x8s0.drp:dis_waveform_time2.csv:0...        185.0  0.124483
# 5   bmp/g4x2_all_A204_26x33.drp:dis_waveform_time2...        159.0  0.134981
# 6   bmp/g2x8_A204_26x33.drp:dis_waveform_time2.csv...        159.0  0.138598
# 7   bmp/g6x8_A204_26x33.drp:dis_waveform_time2.csv...        159.0  0.153962
# 8   bmp/g4x8_A204_26x33.drp:dis_waveform_time2.csv...        159.0  0.154912
# 9   bmp/kk_10X12s0.drp:dis_waveform_time2.csv:0:0:...        287.0  0.174150
# 10    bmp/5X12s1.drp:dis_waveform_time2.csv:0:0:185.0        185.0  0.211295
#
#      Vel var   Vol var
# 0   0.053242  0.001439
# 1   0.049780  0.002028
# 2   0.049570  0.002347
# 3   0.055691  0.002187
# 4   0.053748  0.002316
# 5   0.060457  0.002233
# 6   0.062140  0.002230
# 7   0.058767  0.002620
# 8   0.061715  0.002510
# 9   0.067511  0.002580
# 10  0.066895  0.003159

# %%
# sandbox...
key = vel_vol_scores_sorted[0][0]
pat, wf, volt, clock, pd_delay = key.split(":")
print(f"{pat}, {wf}, {volt}, {clock}, {pd_delay}")
df_good.loc[(df_good['Pattern'] == pat) & (df_good['Waveform'] == wf) & (df_good['Voltage'] == int(volt)) & (df_good['Clock'] == int(clock)) & (df_good['PD_delay_us'] == float(pd_delay)) ]
# Out:
# bmp/kk_8x6s0.drp, dis_waveform_time2.csv, 0, 0, 185.0
#       Experiment Num  LoopID  \
# 1433               2      72
# 1436               2      73
# 1439               2      73
# 1442               2      74
# 1448               2      75
# 1457               2      77
# 1466               2      79
# 1469               2      79
# 1493               2      84
# 1497               2      85
# 1502               2      86
# 1505               2      87
# 1526               2      91
# 1529               2      91
# 1538               2      93
# 1541               2      94
# 1547               2      95
# 1556               2      97
# 1562               2      98
# 1568               2      99
# 1577               2     101
# 1592               2     104
# 1595               2     105
#
#                                               ImageFile           Pattern  \
# 1433  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1436  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1439  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1442  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1448  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1457  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1466  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1469  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1493  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1497  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1502  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1505  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1526  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1529  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1538  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1541  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1547  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1556  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1562  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1568  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1577  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1592  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
# 1595  /media/DIF_DATA/images/2019-04-12_14.22.53/Dis...  bmp/kk_8x6s0.drp
#
#                     Waveform  Voltage  Clock  PD_delay_us  Row  Nozzle    NOI  \
# 1433  dis_waveform_time2.csv        0      0        185.0    1      36  False
# 1436  dis_waveform_time2.csv        0      0        185.0    1      39  False
# 1439  dis_waveform_time2.csv        0      0        185.0    1      42   True
# 1442  dis_waveform_time2.csv        0      0        185.0    1      45  False
# 1448  dis_waveform_time2.csv        0      0        185.0    1      51  False
# 1457  dis_waveform_time2.csv        0      0        185.0    1      60  False
# 1466  dis_waveform_time2.csv        0      0        185.0    1      69  False
# 1469  dis_waveform_time2.csv        0      0        185.0    1      72   True
# 1493  dis_waveform_time2.csv        0      0        185.0    1      96  False
# 1497  dis_waveform_time2.csv        0      0        185.0    1     102   True
# 1502  dis_waveform_time2.csv        0      0        185.0    1     105  False
# 1505  dis_waveform_time2.csv        0      0        185.0    1     108  False
# 1526  dis_waveform_time2.csv        0      0        185.0    1     129  False
# 1529  dis_waveform_time2.csv        0      0        185.0    1     132   True
# 1538  dis_waveform_time2.csv        0      0        185.0    1     141  False
# 1541  dis_waveform_time2.csv        0      0        185.0    1     144  False
# 1547  dis_waveform_time2.csv        0      0        185.0    1     150  False
# 1556  dis_waveform_time2.csv        0      0        185.0    1     159  False
# 1562  dis_waveform_time2.csv        0      0        185.0    1     165  False
# 1568  dis_waveform_time2.csv        0      0        185.0    1     171  False
# 1577  dis_waveform_time2.csv        0      0        185.0    1     180  False
# 1592  dis_waveform_time2.csv        0      0        185.0    1     195  False
# 1595  dis_waveform_time2.csv        0      0        185.0    1     198  False
#
#      Phase  Column Primary  Velocity  Vol_top  Vol_bot  Vol_mean  class  \
# 1433     B       1    True     4.400    0.895    0.903    0.8990      4
# 1436     B       3    True     4.853    0.986    0.979    0.9825      4
# 1439     B       0    True     4.395    0.969    0.999    0.9840      4
# 1442     B       2    True     4.905    0.918    0.947    0.9325      4
# 1448     B       1    True     4.920    0.977    0.961    0.9690      4
# 1457     B       2    True     4.744    0.919    0.953    0.9360      4
# 1466     B       3    True     4.765    0.981    0.994    0.9875      4
# 1469     B       0    True     4.461    0.953    0.957    0.9550      4
# 1493     B       1    True     4.934    0.896    0.948    0.9220      4
# 1497     B       0    True     4.648    0.940    0.994    0.9670      4
# 1502     B       2    True     4.724    0.952    0.964    0.9580      4
# 1505     B       4    True     4.258    0.921    0.918    0.9195      4
# 1526     B       3    True     4.673    0.969    0.995    0.9820      4
# 1529     B       0    True     4.180    0.941    0.927    0.9340      4
# 1538     B       1    True     4.591    0.977    0.987    0.9820      4
# 1541     B       3    True     4.936    0.990    0.981    0.9855      4
# 1547     B       2    True     4.869    0.956    0.940    0.9480      4
# 1556     B       3    True     4.816    0.805    0.821    0.8130      4
# 1562     B       2    True     4.406    0.916    0.918    0.9170      4
# 1568     B       1    True     4.765    0.955    0.969    0.9620      4
# 1577     B       2    True     4.653    0.913    0.942    0.9275      4
# 1592     B       2    True     4.948    0.947    0.945    0.9460      4
# 1595     B       4    True     4.368    0.946    0.917    0.9315      4
#
#            class_label
# 1433  vel_vol_in_range
# 1436  vel_vol_in_range
# 1439  vel_vol_in_range
# 1442  vel_vol_in_range
# 1448  vel_vol_in_range
# 1457  vel_vol_in_range
# 1466  vel_vol_in_range
# 1469  vel_vol_in_range
# 1493  vel_vol_in_range
# 1497  vel_vol_in_range
# 1502  vel_vol_in_range
# 1505  vel_vol_in_range
# 1526  vel_vol_in_range
# 1529  vel_vol_in_range
# 1538  vel_vol_in_range
# 1541  vel_vol_in_range
# 1547  vel_vol_in_range
# 1556  vel_vol_in_range
# 1562  vel_vol_in_range
# 1568  vel_vol_in_range
# 1577  vel_vol_in_range
# 1592  vel_vol_in_range
# 1595  vel_vol_in_range

# %% [markdown]
# #### For each set in the sorted list of best scores:
# - extract the disp settings from the hash (key)
# - use locate to get rows with the dispence settings from the hash
# - append this dataframe to list
#
# ##### ...then use list to create new dataframe with the best results

# %%
best = []
for key, score in vel_vol_scores_sorted:
    pat, wf, volt, clock, pd_delay = key.split(":")
    df_sub = df_good.loc[(df_good['Pattern'] == pat) & (df_good['Waveform'] == wf) & (df_good['Voltage'] == int(volt)) & (df_good['Clock'] == int(clock)) & (df_good['PD_delay_us'] == float(pd_delay)) ]
    print(f"Adding {len(df_sub)} rows with disp settings: {pat}, {wf}, {volt}, {clock}, {pd_delay} -> score: {score}")
    best.append(df_sub)
df_best = pd.concat(best).reset_index(drop=True)
# Out:
# Adding 23 rows with disp settings: bmp/kk_8x6s0.drp, dis_waveform_time2.csv, 0, 0, 185.0 -> score: 0.07659612859297966
# Adding 75 rows with disp settings: bmp/kk_8x2s0.drp, dis_waveform_time2.csv, 0, 0, 185.0 -> score: 0.10096204825481116
# Adding 48 rows with disp settings: bmp/g4x16_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0 -> score: 0.11633470820891383
# Adding 83 rows with disp settings: bmp/g4x4_AB_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0 -> score: 0.12180787380276933
# Adding 87 rows with disp settings: bmp/kk_RowA_8x8s0.drp, dis_waveform_time2.csv, 0, 0, 185.0 -> score: 0.1244828144510174
# Adding 81 rows with disp settings: bmp/g4x2_all_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0 -> score: 0.13498072701837469
# Adding 44 rows with disp settings: bmp/g2x8_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0 -> score: 0.13859848048149712
# Adding 94 rows with disp settings: bmp/g6x8_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0 -> score: 0.15396203809217
# Adding 101 rows with disp settings: bmp/g4x8_A204_26x33.drp, dis_waveform_time2.csv, 0, 0, 159.0 -> score: 0.15491219811388643
# Adding 20 rows with disp settings: bmp/kk_10X12s0.drp, dis_waveform_time2.csv, 0, 0, 287.0 -> score: 0.17415048029146868
# Adding 22 rows with disp settings: bmp/5X12s1.drp, dis_waveform_time2.csv, 0, 0, 185.0 -> score: 0.2112945117606721

# %% [markdown]
# #### Hmmm.  Interesting that there are not many rows added for some of the disp settings.  Lets go back to original data set and see how many of these settings were out of range.

# %%
permuts_disp_settings = list(itertools.product(disp_unique['Pattern'], disp_unique['Waveform'], disp_unique['Voltage'], disp_unique['Clock']))
print(f"Permutation count: {len(permuts_disp_settings)}\n")

for i, permut in enumerate(permuts_disp_settings):
    pat, wf, volt, clock = permut
    key = f"{pat}:{wf}:{volt}:{clock}"
    df_sub = df_full.loc[(df_full['Pattern'] == pat) & (df_full['Waveform'] == wf) & (df_full['Voltage'] == int(volt)) & (df_full['Clock'] == int(clock)) ]
    print(f"For {key}, total rows: {len(df_sub)}:")
    class_labels = ['vel_vol_in_range', 'vol_in_range', 'vel_in_range', 'out_of_range']
    for class_label in class_labels:
        count = len(df_sub.loc[df_sub['class_label'] == class_label, :])
        print(f" ...{count} are {class_label}")

    print("------------------------------------")
# Out:
# Permutation count: 11
#
# For bmp/g4x8_A204_26x33.drp:dis_waveform_time2.csv:0:0, total rows: 200:
#  ...101 are vel_vol_in_range
#  ...10 are vol_in_range
#  ...47 are vel_in_range
#  ...42 are out_of_range
# ------------------------------------
# For bmp/g2x8_A204_26x33.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...44 are vel_vol_in_range
#  ...31 are vol_in_range
#  ...64 are vel_in_range
#  ...36 are out_of_range
# ------------------------------------
# For bmp/g6x8_A204_26x33.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...94 are vel_vol_in_range
#  ...9 are vol_in_range
#  ...40 are vel_in_range
#  ...32 are out_of_range
# ------------------------------------
# For bmp/g4x16_A204_26x33.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...48 are vel_vol_in_range
#  ...7 are vol_in_range
#  ...15 are vel_in_range
#  ...105 are out_of_range
# ------------------------------------
# For bmp/g4x4_AB_A204_26x33.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...83 are vel_vol_in_range
#  ...12 are vol_in_range
#  ...41 are vel_in_range
#  ...39 are out_of_range
# ------------------------------------
# For bmp/g4x2_all_A204_26x33.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...81 are vel_vol_in_range
#  ...12 are vol_in_range
#  ...37 are vel_in_range
#  ...45 are out_of_range
# ------------------------------------
# For bmp/kk_RowA_8x8s0.drp:dis_waveform_time2.csv:0:0, total rows: 190:
#  ...87 are vel_vol_in_range
#  ...15 are vol_in_range
#  ...50 are vel_in_range
#  ...38 are out_of_range
# ------------------------------------
# For bmp/kk_8x2s0.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...75 are vel_vol_in_range
#  ...12 are vol_in_range
#  ...55 are vel_in_range
#  ...33 are out_of_range
# ------------------------------------
# For bmp/kk_8x6s0.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...23 are vel_vol_in_range
#  ...7 are vol_in_range
#  ...16 are vel_in_range
#  ...129 are out_of_range
# ------------------------------------
# For bmp/5X12s1.drp:dis_waveform_time2.csv:0:0, total rows: 175:
#  ...22 are vel_vol_in_range
#  ...10 are vol_in_range
#  ...10 are vel_in_range
#  ...133 are out_of_range
# ------------------------------------
# For bmp/kk_10X12s0.drp:dis_waveform_time2.csv:0:0, total rows: 180:
#  ...20 are vel_vol_in_range
#  ...13 are vol_in_range
#  ...12 are vel_in_range
#  ...135 are out_of_range
# ------------------------------------

# %% [markdown]
# ### Oce Waveform Generation Experiment Analysis
# - Unlike the normal experiments, these have 19 waveform parameters that are used to generate a waveform on-the-fly
# - This means 2^19 permutations of dispense parameters, to many to make sense of using techniques above

# %%
# this is so i can cut-n-paste code straight out of DIF script
import logging
from importlib import reload
reload(logging)

logger = logging.getLogger()
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')
logging.debug("test")
# Out:
# 09:47:25 DEBUG:test

# %%
expFolder = paths.tmp_dir + '/DIF/DOE_2019-11-07_16.22.46'
result_files = glob.glob("%s/full_results_[0-9].csv" % (expFolder))
result_files
# Out:
# ['/Users/trafferty/tmp/DIF/DOE_2019-11-07_16.22.46/full_results_1.csv']

# %%
loop_event_dict = {
  "id": 5,
  "type": "event",
  "event": "loop_update",
  "loop_vars": {
    "Run Mode": "Recipe",
    "LoopParmsCnt": 0,
    "Camera": "Andor",
    "DIF_Version": "0.2.0",
    "DispenseBitmapFile": "bmp/g4x8_C204_26x33.drp",
    "Dispenser_Type": "Oce",
    "Elapsed_Time": "4.205981 sec",
    "Est_Completion_Time": "2019-10-28 11:39:20",
    "ExpFolder": expFolder,
    "ExperimentID": "ExpTag_123",
    "ExperimentIndex": "1",
    "ExperimentType": "DispenserOptOnDemand",
    "HeadName": "Xaar100x",
    "HeadSerialNumber": "SNX095438",
    "ImageFile": "/Users/trafferty/tmp/DIF/DOE_2019-11-07_16.22.46/DispenserOptOnDemand_02_00003_2019-10-28_11.39.18.png",
    "ImageID": "3",
    "Location": "DIF Station",
    "Loop_Count": "3",
    "Magnification": "20x",
    "Mean_Time_per_Loop": "1.401994 sec",
    "MonomerID": "787A",
    "Nozzle": "100.000000",
    "NozzleID": "100.000000",
    "PD_delay_us": "85.000000",
    "PD_start_us": "15506.442500",
    "Phase": "C",
    "PrimaryNozzles": "3,0",
    "Row": "1.000000",
    "SecondaryNozzles": "1,2,4,5",
    "Total_Loops": "4",
    "WF_vals_vals": "AA:10,AB:-25,AC:15,AD:-6,AE:3.6,AF:2.4,BI:30,CA:0.4,CB:1,CC:0.5,CD:0.5,CE:1.5,CF:0.5,HT:0.6,PA:0.1,PB:0.2,PC:0.3,PD:1,WT:1",
    "Waveform": "dis_waveform_onDemand_iter_2.csv",
    "cam1_int_start_us": "1.000000",
    "cam2_int_start_us": "21001.000000",
    "cam3_int_start_us": "42001.000000",
    "cycle_time_us": "21000.000000",
    "del_WF_file": "/home/trafferty/workspace/def/dis_waveform_onDemand_iter_2.csv",
    "double_shutter": "true",
    "double_shutter_delay_us": "4.000000",
    "drop_latency_us": "117.000000",
    "drop_pattern_gap_us": "5291.557500",
    "elapsed_ms": "822.290897",
    "git-branch": "dif_new_processing",
    "git-sha": "87da7e144aa398432703cd95a0ad11d424d4d493",
    "lamp1_start_us": "20865.000000",
    "lamp2_start_us": "20875.000000",
    "on_demand_iter": "2.000000",
    "qsw1_start_us": "21000.000000",
    "qsw2_start_us": "21004.000000",
    "start_time_us": "1.000000"
  },
  "need_processing": True
}

postProcess_recipe={
 "name": "BasicResults_PostProcessor",
  "vel_desired_range": [4.0, 6.5],
  "vol_desired_range": [0.5, 0.7]
}

config={
}

# %%
last_loop_vars = loop_event_dict["loop_vars"]

postProcessStep_dict = postProcess_recipe

vol_desired_range = postProcessStep_dict["vol_desired_range"]
vel_desired_range = postProcessStep_dict["vel_desired_range"]

# Setup path for result folder and glob all of the result file paths into list
result_root = last_loop_vars["ExpFolder"] + '/'
result_files = glob.glob("%s/full_results_[0-9].csv" % (result_root))

num_result_sets = len(result_files)
if num_result_sets == 0:
    logger.error(f"No results files found! Skipping. {image_stats_fname}")
else:
    logger.info(f"Found {num_result_sets} result file(s) to process.")

# Combine all of the result files into one
df_list = []
for i, f in enumerate(result_files):
    df_sub = pd.read_csv(f)
    df_sub.insert(0, 'Experiment Num', i+1)
    logger.info(f"...read in {len(df_sub)} from {f}")
    df_list.append(df_sub)
df_full = pd.concat(df_list).reset_index(drop=True)
logger.info(f"Total datapoints read: {len(df_full)}")

# Fix header fields, which have leading space in it
df_full.columns = [field.strip() for field in df_full.columns]

# ...and also the columns with string data:
for col_name in df_full.columns:
    if df_full[col_name].dtype == 'O':
        logger.debug(f"Stripping column {col_name}, which is dtype 'O'")
        df_full[col_name] = df_full[col_name].str.strip()

# Now fix the Velocity, Vol_top and Vol_bot series (convert to float, replace 'n/a' with NaN)
for field in ['Velocity', 'Vol_top', 'Vol_bot']:
    df_full[field] = pd.to_numeric(df_full[field], errors='coerce')

# Create new column with mean volume
df_full['Vol_mean'] = (df_full['Vol_top'] + df_full['Vol_bot']) / 2.0
# Out:
# 09:47:27 INFO:Found 1 result file(s) to process.
# 09:47:28 INFO:...read in 81295 from /Users/trafferty/tmp/DIF/DOE_2019-11-07_16.22.46/full_results_1.csv
# 09:47:28 INFO:Total datapoints read: 81295
# 09:47:28 DEBUG:Stripping column ImageFile, which is dtype 'O'
# 09:47:28 DEBUG:Stripping column Pattern, which is dtype 'O'
# 09:47:28 DEBUG:Stripping column Waveform, which is dtype 'O'
# 09:47:28 DEBUG:Stripping column Phase, which is dtype 'O'

# %%
# Define some functions to use for classifying results based on volume and velocity ranges
def calc_class_str(vol, vel):
    vol_in_range = True if vol >= vol_desired_range[0] and vol <= vol_desired_range[1] else False
    vel_in_range = True if vel >= vel_desired_range[0] and vel <= vel_desired_range[1] else False
    if vol_in_range and vel_in_range:
        return 'vel_vol_in_range'
    elif vol_in_range:
        return 'vol_in_range'
    elif vel_in_range:
        return 'vel_in_range'
    else:
        return 'out_of_range'

def calc_class(vol, vel):
    vol_in_range = True if vol >= vol_desired_range[0] and vol <= vol_desired_range[1] else False
    vel_in_range = True if vel >= vel_desired_range[0] and vel <= vel_desired_range[1] else False
    if vol_in_range and vel_in_range:
        return 4
    elif vol_in_range:
        return 2
    elif vel_in_range:
        return 1
    else:
        return 0

# %%
'''
Now, execute these functions for all rows in dataframe, creating new columns for class:
    vel_vol_in_range (4): Both velocity and volume in desired range
    vol_in_range (2): Volume only in desired range
    vel_in_range (1): Velocity only in desired range
    out_of_range (0): Neither velocity or volume in desired range
'''
df_full['class'] = np.vectorize(calc_class)(df_full['Vol_mean'], df_full['Velocity'])
df_full['class_label'] = np.vectorize(calc_class_str)(df_full['Vol_mean'], df_full['Velocity'])

# ax = df_full.plot(x='Vol_mean', y='Velocity', kind = 'scatter', c ='class', colormap='viridis')
# fig = ax.get_figure()
# fig.savefig(f"{self.expFolder}/scatter_vol_vel.png")

# Create dataframe with just the rows with velocity and volumes in desired ranges
df_good = df_full.loc[df_full['class'] == 4, :]

# but first, let's do some stats to make sure we have values in the desired range to work with 
num_full         = len(df_full)
num_good         = len(df_good)
num_vel_only     = len(df_full.loc[df_full['class'] == 1, :])
num_vol_only     = len(df_full.loc[df_full['class'] == 2, :])
num_out_of_range = len(df_full.loc[df_full['class'] == 0, :])

logger.info(f"   Num vel and vol in range: {num_good} ({((num_good/num_full)*100):.2f}%)")
logger.info(f" Num velocity only in range: {num_vel_only} ({((num_vel_only/num_full)*100):.2f}%)")
logger.info(f"   Num volume only in range: {num_vol_only} ({((num_vol_only/num_full)*100):.2f}%)")
logger.info(f"           Num out of range: {num_out_of_range} ({((num_out_of_range/num_full)*100):.2f}%)")

if num_good == 0:
    logger.warn("No results within desired range :( Stopping analysis... ")
# Out:
# 09:47:30 INFO:   Num vel and vol in range: 2177 (2.68%)
# 09:47:30 INFO: Num velocity only in range: 14809 (18.22%)
# 09:47:30 INFO:   Num volume only in range: 6686 (8.22%)
# 09:47:30 INFO:           Num out of range: 57623 (70.88%)

# %%
'''
Categorize some columns as certain types:
    disp_settings: dispenser settings
    nozzle_settings: nozzle settings
    image_settings: image settings
'''
if "Dispenser_Type" in last_loop_vars:
    if last_loop_vars["Dispenser_Type"] == "Xaar":
        res_type = "xaar"
        logger.info("Processing results type: Xaar")
        disp_settings = ['Pattern', 'Waveform', 'Voltage', 'Clock', 'PD_delay_us']
    elif last_loop_vars["Dispenser_Type"] == "Oce":
        if "WF_vals_vals" in last_loop_vars and len(last_loop_vars["WF_vals_vals"]) > 0:
            res_type = "oce_wf_gen"
            logger.info("Processing results type: Oce with waveform synthesis")
            disp_settings = ['Pattern', 'BI', 'AA', 'AB', 'AC', 'AD', 'AE', 'AF', 'WT', 'CA', 'HT', 'CB', 'PA', 'CC', 'PB', 'CD', 'PC', 'CE', 'PD', 'CF', 'PD_delay_us']
            #disp_settings = ['Pattern', 'BI', 'AA', 'AB', 'AC', 'CE', 'PD', 'CF', 'PD_delay_us']
        else:
            res_type = "oce"
            logger.info("Processing results type: Oce (no waveform synthesis)")
            disp_settings = ['Pattern', 'Waveform', 'PD_delay_us']
    else:
        logger.info("Processing results type: Not Set!")
        disp_settings = ['Pattern', 'Waveform', 'PD_delay_us']

nozzle_settings = ['Row', 'Nozzle', 'Phase']
image_settings = ['NOI', 'Column', 'Primary']
# Out:
# 09:47:31 INFO:Processing results type: Oce with waveform synthesis

# %%
# Now, for each category, get list of unique values for that column, put in dict for later
disp_unique = {}
disp_unique_list = []
for disp_setting in disp_settings:
    disp_unique[disp_setting] = list(df_good[disp_setting].unique())
    disp_unique_list.append(disp_unique[disp_setting])
logger.info(f"Unique dispenser settings:\n{disp_unique}")

nozzle_unique = {}
for nozzle_setting in nozzle_settings:
    nozzle_unique[nozzle_setting] = list(df_good[nozzle_setting].unique())
logger.info(f"\nUnique nozzle settings:\n{nozzle_unique}")

image_unique = {}
for image_setting in image_settings:
    image_unique[image_setting] = list(df_good[image_setting].unique())
logger.info(f"\nUnique image settings:\n{image_unique}")

# For the unique dispense setting values, create a list of all permutations of these settings
# permuts = list(itertools.product(disp_unique['Pattern'], disp_unique['Waveform'], disp_unique['Voltage'], disp_unique['Clock'], disp_unique['PD_delay_us']))
# print(f"Permutation count: {len(permuts)}")

permuts = list(itertools.product(*disp_unique_list))
logger.info(f"Permutation count: {len(permuts)}")
# Out:
# 09:47:32 INFO:Unique dispenser settings:
# {'Pattern': ['bmp/g4x8_D204_26x33.drp'], 'BI': [20, 25], 'AA': [15, 10], 'AB': [-20, -25], 'AC': [10, 15], 'AD': [-6, -3], 'AE': [2.0, 3.6], 'AF': [2.4, 4.0], 'WT': [0.1, 1.0], 'CA': [0.6, 0.4], 'HT': [0.8, 0.6], 'CB': [1.5, 1.0], 'PA': [0.1, 0.4], 'CC': [0.5, 0.8], 'PB': [0.7, 0.2], 'CD': [0.5, 1.0], 'PC': [0.3, 0.6], 'CE': [1.0, 1.5], 'PD': [1.5, 1.0], 'CF': [0.5, 1.0], 'PD_delay_us': [0.0]}
# 09:47:32 INFO:
# Unique nozzle settings:
# {'Row': [4], 'Nozzle': [96, 97, 99, 100, 98], 'Phase': ['B', 'C', 'A']}
# 09:47:32 INFO:
# Unique image settings:
# {'NOI': [False, True], 'Column': [4, 3, 1, 0, 2], 'Primary': [True]}
# 09:47:32 INFO:Permutation count: 524288

# %%
df = pd.DataFrame(
    np.random.rand(100, 5),
    columns=['a', 'b', 'c', 'd', 'e']
)
#df.profile_report(style={'full_width':True})

profile = pandas_profiling.ProfileReport(df_good)
profile.to_file("output.html")

# %%
df_good.hist(disp_settings,  layout=(10,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129a41128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1298e3e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129a6ccc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129c22780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129c53240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129c53278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129ca8780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129cd7240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129cfbcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129d2c780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129d5b240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129d7ecc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129dae780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129ddf240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129e05cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129e33780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129e62240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129e87cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129eb5780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129ee7240>]],
#       dtype=object)

# %%
(df_good['AA']==15).sum()
# Out:
# 906

# %%
bar_len = 180
char = '='


target_str = f"vol:{vol_desired_range[0]:.2}-{vol_desired_range[1]:.2}_vel:{vel_desired_range[0]:.2}-{vel_desired_range[1]:.2}"
labels = []
low_vals = []
hi_vals = []
low_counts = []
hi_counts = []

for idx, disp_setting in enumerate(disp_settings):
    #print(disp_setting)
    if len(disp_unique_list[idx]) > 1:
        low_val = disp_unique_list[idx][0]
        low_val_count = (df_good[disp_setting]==low_val).sum()
        hi_val = disp_unique_list[idx][1]
        hi_val_count = (df_good[disp_setting]==hi_val).sum()
        total = low_val_count+hi_val_count
        print(f"{disp_setting} @ {low_val:4}: {low_val_count:5} {char * (int(bar_len*( low_val_count/total )))}")
        print(f"{disp_setting} @ {hi_val:4}: {hi_val_count:5} {char * (int(bar_len*( hi_val_count/total  )))}")
        print("----------")
        
        labels.append(disp_setting)
        low_vals.append(low_val)
        hi_vals.append(hi_val)
        low_counts.append(low_val_count)
        hi_counts.append(hi_val_count)

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots(figsize=(20, 10))
rects1 = ax.bar(x - width/2, low_counts, width, label='Low')
rects2 = ax.bar(x + width/2, hi_counts, width, label='High')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_title(f'Distribution of Oce waveform params in target range: {target_str}')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects, vals):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect, val in zip(rects, vals):
        height = rect.get_height()
        ax.annotate('({})'.format(val),
                    xy=(rect.get_x() + rect.get_width() / 2, height+20),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1, low_vals)
autolabel(rects2, hi_vals)

fig.tight_layout()

plt.show()
fig.savefig(f"waveform_param_dist_{target_str}.png")
# Out:
# BI @   20:  1279 =========================================================================================================
# BI @   25:   898 ==========================================================================
# ----------
# AA @   15:   906 ==========================================================================
# AA @   10:  1271 =========================================================================================================
# ----------
# AB @  -20:  1182 =================================================================================================
# AB @  -25:   995 ==================================================================================
# ----------
# AC @   10:  1125 =============================================================================================
# AC @   15:  1052 ======================================================================================
# ----------
# AD @   -6:  1399 ===================================================================================================================
# AD @   -3:   778 ================================================================
# ----------
# AE @  2.0:  1192 ==================================================================================================
# AE @  3.6:   985 =================================================================================
# ----------
# AF @  2.4:  1291 ==========================================================================================================
# AF @  4.0:   886 =========================================================================
# ----------
# WT @  0.1:  1088 =========================================================================================
# WT @  1.0:  1089 ==========================================================================================
# ----------
# CA @  0.6:  1237 ======================================================================================================
# CA @  0.4:   940 =============================================================================
# ----------
# HT @  0.8:  1100 ==========================================================================================
# HT @  0.6:  1077 =========================================================================================
# ----------
# CB @  1.5:  1114 ============================================================================================
# CB @  1.0:  1063 =======================================================================================
# ----------
# PA @  0.1:  1224 =====================================================================================================
# PA @  0.4:   953 ==============================================================================
# ----------
# CC @  0.5:  1215 ====================================================================================================
# CC @  0.8:   962 ===============================================================================
# ----------
# PB @  0.7:  1152 ===============================================================================================
# PB @  0.2:  1025 ====================================================================================
# ----------
# CD @  0.5:  1087 =========================================================================================
# CD @  1.0:  1090 ==========================================================================================
# ----------
# PC @  0.3:  1088 =========================================================================================
# PC @  0.6:  1089 ==========================================================================================
# ----------
# CE @  1.0:  1113 ============================================================================================
# CE @  1.5:  1064 =======================================================================================
# ----------
# PD @  1.5:  1125 =============================================================================================
# PD @  1.0:  1052 ======================================================================================
# ----------
# CF @  0.5:  1100 ==========================================================================================
# CF @  1.0:  1077 =========================================================================================
# ----------

# %%
# Out:
# -130380
