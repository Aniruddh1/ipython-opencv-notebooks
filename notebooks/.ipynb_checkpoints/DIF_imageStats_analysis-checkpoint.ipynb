# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import glob
import itertools
from collections import namedtuple

import matplotlib.ticker as ticker
from sklearn import preprocessing

# looks good in dark mode:
plt.style.use(['seaborn-dark-palette'])

import sys
from paths import Paths
paths = Paths()
sys.path.append(paths.scripts_root)
import util

# %load_ext autoreload
# %autoreload 2

# Display entire width of browser
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

paths.print_paths()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Paths defined in paths module:
#  paths.data_root: /Users/trafferty/data
#  paths.notebook_root: /Users/trafferty/data/notebooks
#  paths.scripts_root: /Users/trafferty/data/scripts
#  paths.images_root: /Users/trafferty/data/images
#  paths.projects_root: /Users/trafferty/data/projects
#  paths.results_root: /Users/trafferty/data/results
#  paths.tmp_root: /Users/trafferty/data/tmp
#  paths.dat_root: /Users/trafferty/data/dat
#  paths.tmp_dir: /Users/trafferty/tmp
#  paths.ws_dir: /Users/trafferty/workspace
#  paths.mii_home: /Users/trafferty/dev
#  paths.inhouse: /Users/trafferty/dev/src/inhouse

# %%
result_path = f"{paths.tmp_dir}/DIF/DIF1_Jason_Qi_long_test"

ip_results_df = pd.read_csv(f"{result_path}/full_results_0.csv")
image_stats_df = pd.read_csv(f"{result_path}/image_stats.csv")

# %%
# Fix the Velocity, Vol_top and Vol_bot series (convert to float, replace 'n/a' with NaN)
for field in ['Velocity', 'Vol_top', 'Vol_bot']:
    ip_results_df[field] = pd.to_numeric(ip_results_df[field], errors='coerce')

# %%
# Fix the image stat column names
image_stats_df.columns = [field.strip() for field in image_stats_df.columns]
image_stats_df.columns
# Out:
# Index(['LoopID', 'ImageFile', 'Top Saturation', 'Top Min', 'Top Max',
#        'Top Mean', 'Bot Saturation', 'Bot Min', 'Bot Max', 'Bot Mean'],
#       dtype='object')

# %%
Stats = namedtuple('Stats', 'n mean std var')

def get_stats(ip_df, print_stats = False):
    stats = {}
    stats['Velocity'] = Stats(ip_df['Velocity'].count(), np.mean(ip_df['Velocity']), np.std(ip_df['Velocity']), np.var(ip_df['Velocity']))
    stats['Vol_top']  = Stats(ip_df['Vol_top'].count(), np.mean(ip_df['Vol_top']),  np.std(ip_df['Vol_top']),  np.var(ip_df['Vol_top']))
    stats['Vol_bot']  = Stats(ip_df['Vol_bot'].count(), np.mean(ip_df['Vol_bot']),  np.std(ip_df['Vol_bot']),  np.var(ip_df['Vol_bot']))
    if print_stats:
        print("             num  \tMean \tStdev \tVariance")
        print(f" Velocity:   {stats['Velocity'].n:5}\t{stats['Velocity'].mean:.3f}\t{stats['Velocity'].std:.3f} \t{stats['Velocity'].var:.3f}")
        print(f" Vol_top :   {stats['Vol_top'].n:5}\t{stats['Vol_top'].mean:.3f}\t{stats['Vol_top'].std:.3f} \t{stats['Vol_top'].var:.3f}")
        print(f" Vol_bot :   {stats['Vol_bot'].n:5}\t{stats['Vol_bot'].mean:.3f}\t{stats['Vol_bot'].std:.3f} \t{stats['Vol_bot'].var:.3f}")
    return stats

# %%
s =get_stats(ip_results_by_nozzle_df[300], True)
# Out:
#              num  	Mean 	Stdev 	Variance
#  Velocity:    9971	5.420	0.080 	0.006
#  Vol_top :    9971	0.738	0.122 	0.015
#  Vol_bot :    9971	0.693	0.135 	0.018

# %%
image_stats_df.head()
# Out:
#    LoopID                                          ImageFile   Top Saturation  \
# 0       1  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.470187
# 1       2  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.471469
# 2       3  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.461924
# 3       4  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.458772
# 4       5  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.465921
#
#     Top Min   Top Max      Top Mean   Bot Saturation   Bot Min   Bot Max  \
# 0      2631     65254  30814.199414         0.378838      2162     65535
# 1      2692     65535  30898.204485         0.375421      2210     65515
# 2      2704     65535  30272.637928         0.381119      2434     65443
# 3      2825     65535  30066.097748         0.381409      2486     65278
# 4      2889     65535  30534.619410         0.375223      2465     65491
#
#        Bot Mean
# 0  24827.537878
# 1  24603.591136
# 2  24977.029797
# 3  24995.994272
# 4  24590.647152

# %%
ip_results_df.head(10)
# Out:
#    LoopID  Repeat                                          ImageFile  \
# 0       1     1.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 1       1     1.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 2       1     1.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 3       1     1.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 4       1     1.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 5       1     1.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 6       2     2.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 7       2     2.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 8       2     2.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 9       2     2.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
#
#                                       Pattern           Waveform  Voltage  \
# 0  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 1  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 2  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 3  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 4  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 5  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 6  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 7  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 8  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 9  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
#
#    Clock  PD_delay_us  Row  Nozzle    NOI Phase  Column  Primary  Velocity  \
# 0  120.0        250.0    1     299  False     A       5    False     4.980
# 1  120.0        250.0    1     300   True     B       4     True     5.383
# 2  120.0        250.0    1     301  False     C       3    False     5.125
# 3  120.0        250.0    1     302  False     A       2    False     4.767
# 4  120.0        250.0    1     303  False     B       1     True     5.419
# 5  120.0        250.0    1     304  False     C       0    False     5.366
# 6  120.0        250.0    1     299  False     A       5    False     4.968
# 7  120.0        250.0    1     300   True     B       4     True     5.375
# 8  120.0        250.0    1     301  False     C       3    False     5.118
# 9  120.0        250.0    1     302  False     A       2    False     4.763
#
#    Vol_top  Vol_bot
# 0    0.603    0.501
# 1    0.902    0.869
# 2    0.555    0.541
# 3    0.681    0.624
# 4    0.873    0.899
# 5    0.582    0.645
# 6    0.614    0.508
# 7    0.903    0.896
# 8    0.567    0.545
# 9    0.707    0.628

# %% [markdown]
# #### Image Processing Analysis
# - Stats (mean, stdev, variance) of Velocity, Vol_top and Vol_bot of each column

# %%
nozzle_lst = ip_results_df['Nozzle'].unique()
nozzle_stats = {}
ip_results_by_nozzle_df = {}
for nozzle in nozzle_lst:
    print(f"----------------------------------------------------\nProcessing nozzle {nozzle}")
    ip_results_by_nozzle_df[nozzle] = ip_results_df[ip_results_df['Nozzle'] == nozzle]
    nozzle_stats[nozzle] = get_stats(ip_nozzle_results_df[nozzle], True)
# Out:
# ----------------------------------------------------
# Processing nozzle 299
#              num  	Mean 	Stdev 	Variance
#  Velocity:       9	5.055	0.073 	0.005
#  Vol_top :       9	0.605	0.016 	0.000
#  Vol_bot :       9	0.503	0.012 	0.000
# ----------------------------------------------------
# Processing nozzle 300
#              num  	Mean 	Stdev 	Variance
#  Velocity:    9971	5.420	0.080 	0.006
#  Vol_top :    9971	0.738	0.122 	0.015
#  Vol_bot :    9971	0.693	0.135 	0.018
# ----------------------------------------------------
# Processing nozzle 301
#              num  	Mean 	Stdev 	Variance
#  Velocity:   10000	5.215	0.075 	0.006
#  Vol_top :   10000	0.640	0.077 	0.006
#  Vol_bot :   10000	0.650	0.088 	0.008
# ----------------------------------------------------
# Processing nozzle 302
#              num  	Mean 	Stdev 	Variance
#  Velocity:    3484	4.852	0.051 	0.003
#  Vol_top :    3484	0.653	0.034 	0.001
#  Vol_bot :    3484	0.567	0.036 	0.001
# ----------------------------------------------------
# Processing nozzle 303
#              num  	Mean 	Stdev 	Variance
#  Velocity:    9967	5.460	0.079 	0.006
#  Vol_top :    9967	0.814	0.076 	0.006
#  Vol_bot :    9967	0.769	0.113 	0.013
# ----------------------------------------------------
# Processing nozzle 304
#              num  	Mean 	Stdev 	Variance
#  Velocity:    9999	5.514	0.075 	0.006
#  Vol_top :    9999	0.800	0.127 	0.016
#  Vol_bot :    9999	0.811	0.140 	0.020

# %%
noz_302_df = ip_results_by_nozzle_df[302]

# %%
ip_results_by_nozzle_df[nozzle].iloc[0]['Column']
# Out:
# 0

# %%
fig, ax = plt.subplots(figsize=(30, 20))
for idx, nozzle in enumerate(nozzle_lst):
    col = ip_results_by_nozzle_df[nozzle].iloc[0]['Column']
    phase = ip_results_by_nozzle_df[nozzle].iloc[0]['Phase']
    primary = ip_results_by_nozzle_df[nozzle].iloc[0]['Primary']
    c = 'P' if primary else 'S'
    #clr = 'blue' if primary else 'gray'
    ip_results_by_nozzle_df[nozzle].loc[ :, ['Velocity']].plot(ax=ax, y='Velocity', label=f"Velocity Noz {nozzle} (col {col}, {phase}, {c})", grid=True)

ticks_x = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/6))
ax.xaxis.set_major_formatter(ticks_x)
ax.set_ylabel("Velocity")
ax.set_title("Velocity Per Nozzle (image column)")
plt.savefig(f"{result_path}/DIF1_10000cycle_velocity.png")

# %%
start, end = 21400, 22000
start, end = 0, 60000
fig, ax1 = plt.subplots(figsize=(30, 20))
for idx, nozzle in enumerate(nozzle_lst):
    col = ip_results_by_nozzle_df[nozzle].iloc[0]['Column']
    phase = ip_results_by_nozzle_df[nozzle].iloc[0]['Phase']
    primary = ip_results_by_nozzle_df[nozzle].iloc[0]['Primary']
    c = 'P' if primary else 'S'
    clr = 'blue' if primary else 'gray'
    ip_results_by_nozzle_df[nozzle].loc[ start:end, ['Vol_top']].plot(ax=ax1, y='Vol_top',label=f"Volume Noz {nozzle} (col {col}, {phase}, {c})", grid=True)

ticks_x = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/6))
ax1.xaxis.set_major_formatter(ticks_x)

ax1.set_ylabel("Volume (pl)")
ax1.set_title("Volume Per Nozzle (image column)")
plt.savefig(f"{result_path}/DIF1_10000cycle_volume.png")

# %%
# looks good in dark mode:
plt.style.use(['seaborn-dark-palette'])

fig, ax1 = plt.subplots(figsize=(30, 20))
grouped_df = ip_results_df.groupby('Nozzle')
grouped_df.plot(y='Velocity', ax=ax1)
# Out:
# Nozzle
# 299    AxesSubplot(0.125,0.125;0.775x0.755)
# 300    AxesSubplot(0.125,0.125;0.775x0.755)
# 301    AxesSubplot(0.125,0.125;0.775x0.755)
# 302    AxesSubplot(0.125,0.125;0.775x0.755)
# 303    AxesSubplot(0.125,0.125;0.775x0.755)
# 304    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
noz_302_ip_df = ip_results_by_nozzle_df[302]

# %%
noz_302_ip_df.tail()
# Out:
#        LoopID   Repeat                                          ImageFile  \
# 59973    9996   9996.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 59979    9997   9997.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 59985    9998   9998.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 59991    9999   9999.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
# 59997   10000  10000.0  /media/DIF_DATA/images/2536865/2019-05-09_10.3...
#
#                                           Pattern           Waveform  Voltage  \
# 59973  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 59979  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 59985  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 59991  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
# 59997  recipe/miss_fire_test_g32x2_15000lines.bmp  F888_TS_110NS.txt     20.0
#
#        Clock  PD_delay_us  Row  Nozzle    NOI Phase  Column  Primary  \
# 59973  120.0        250.0    1     302  False     A       2    False
# 59979  120.0        250.0    1     302  False     A       2    False
# 59985  120.0        250.0    1     302  False     A       2    False
# 59991  120.0        250.0    1     302  False     A       2    False
# 59997  120.0        250.0    1     302  False     A       2    False
#
#        Velocity  Vol_top  Vol_bot
# 59973       NaN      NaN      NaN
# 59979       NaN      NaN      NaN
# 59985       NaN      NaN      NaN
# 59991       NaN      NaN      NaN
# 59997       NaN      NaN      NaN

# %%
noz_302_ip_df['Velocity'].last_valid_index()
#noz_302_ip_df.iloc[idx]['Velocity']
# Out:
# 21801

# %%
ip_results_df.loc[21801]['ImageFile']
# Out:
# '/media/DIF_DATA/images/2536865/2019-05-09_10.32.02/DispenserOpt_03634_2019-05-09_16.35.13.png'

# %%
image_stats_df.head()
# Out:
#    LoopID                                          ImageFile   Top Saturation  \
# 0       1  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.470187
# 1       2  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.471469
# 2       3  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.461924
# 3       4  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.458772
# 4       5  /media/DIF_DATA/images/2536865/2019-05-09_10.3...         0.465921
#
#     Top Min   Top Max      Top Mean   Bot Saturation   Bot Min   Bot Max  \
# 0      2631     65254  30814.199414         0.378838      2162     65535
# 1      2692     65535  30898.204485         0.375421      2210     65515
# 2      2704     65535  30272.637928         0.381119      2434     65443
# 3      2825     65535  30066.097748         0.381409      2486     65278
# 4      2889     65535  30534.619410         0.375223      2465     65491
#
#        Bot Mean
# 0  24827.537878
# 1  24603.591136
# 2  24977.029797
# 3  24995.994272
# 4  24590.647152

# %%
col_lst = ['Top Mean', 'Bot Mean']
for col_name in col_lst:
    x = image_stats_df[[col_name]].values.astype(float)
    min_max_scaler = preprocessing.MinMaxScaler()
    image_stats_df[col_name+' Scaled'] = pd.DataFrame(min_max_scaler.fit_transform(x))
image_stats_df.head()
# Out:
#    LoopID                                          ImageFile  Top Saturation  \
# 0       1  /media/DIF_DATA/images/2536865/2019-05-09_10.3...        0.470187
# 1       2  /media/DIF_DATA/images/2536865/2019-05-09_10.3...        0.471469
# 2       3  /media/DIF_DATA/images/2536865/2019-05-09_10.3...        0.461924
# 3       4  /media/DIF_DATA/images/2536865/2019-05-09_10.3...        0.458772
# 4       5  /media/DIF_DATA/images/2536865/2019-05-09_10.3...        0.465921
#
#    Top Min  Top Max      Top Mean  Bot Saturation  Bot Min  Bot Max  \
# 0     2631    65254  30814.199414        0.378838     2162    65535
# 1     2692    65535  30898.204485        0.375421     2210    65515
# 2     2704    65535  30272.637928        0.381119     2434    65443
# 3     2825    65535  30066.097748        0.381409     2486    65278
# 4     2889    65535  30534.619410        0.375223     2465    65491
#
#        Bot Mean  Top Mean Scaled  Bot Mean Scaled
# 0  24827.537878         0.897411         0.933568
# 1  24603.591136         0.914644         0.885311
# 2  24977.029797         0.786315         0.965781
# 3  24995.994272         0.743945         0.969868
# 4  24590.647152         0.840058         0.882522

# %%
fig, axes = plt.subplots(2, 1, figsize=(30, 20))

for col_name in ['Top Mean', 'Bot Mean']:
    image_stats_df[col_name].plot(ax=axes[0], y=col_name, label=col_name)
axes[0].set_ylabel("Image Intensity - Mean Pixel Value (0-65K)")
axes[0].set_title("Image Intensity - Mean Pixel Value (0-65K)")
axes[0].legend()

for col_name in ['Top Saturation', 'Bot Saturation']:
    image_stats_df[col_name].plot(ax=axes[1], y=col_name, label=col_name)
axes[1].set_ylabel("Image Saturation - Percent")
axes[1].set_title("Image Saturation - Percent")
axes[1].legend()

plt.savefig(f"{result_path}/DIF1_10000cycle_imageIntensity.png")
plt.show()

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']
