# %% [markdown]
# ### Good first cell for image processing

# %%
# %matplotlib notebook
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import os
import itertools
from collections import namedtuple

import sys
from paths import Paths
paths = Paths()
sys.path.append(paths.scripts_root)
import util

# %load_ext autoreload
# %autoreload 2

# Display entire width of browser
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

#paths.print_paths()
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Paths defined in paths module:
#  paths.data_root: /Users/trafferty/data
#  paths.notebook_root: /Users/trafferty/data/notebooks
#  paths.scripts_root: /Users/trafferty/data/scripts
#  paths.images_root: /Users/trafferty/data/images
#  paths.projects_root: /Users/trafferty/data/projects
#  paths.results_root: /Users/trafferty/data/results
#  paths.tmp_root: /Users/trafferty/data/tmp
#  paths.dat_root: /Users/trafferty/data/dat
#  paths.tmp_dir: /Users/trafferty/tmp
#  paths.ws_dir: /Users/trafferty/workspace
#  paths.mii_home: /Users/trafferty/dev
#  paths.inhouse: /Users/trafferty/dev/src/inhouse

# %% [markdown]
# ### Python 3 glob using Path module

# %%
from pathlib import Path

sample_image_path = '/path/to/root/folder'
img_path_list = [img_path for img_path in Path(sample_image_path).glob('**/*.png')]

# %% [markdown]
# ### Plot single images

# %%
fname = f'{paths.images_root}/uat_big.png'

img = cv2.imread(f'{paths.images_root}/uat_big.png')
plt.imshow(img, cmap=plt.cm.gray_r, interpolation='nearest')
plt.title(f'Image path: {fname}')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Plot multiple images

# %%
img_path_lst = [
 f'{paths.images_root}/uat_23x25.png',
 f'{paths.images_root}/uat_24x24.png',
 f'{paths.images_root}/uat_26x28.png',
 f'{paths.images_root}/uat_38x40.png',
 f'{paths.images_root}/UAT_array_01.png',
 f'{paths.images_root}/UAT_array_02.png',
 f'{paths.images_root}/uat_big.png']

img_lst = [cv2.imread(img_path ,cv2.IMREAD_GRAYSCALE) for img_path in img_path_lst ]

# %%
# using my util module:
util.plot_imgs([(img_lst[0],'image 0'), (img_lst[2],'image 2')], max_cols = 3)

# %%
plt_lst = [ (img, f"Image index {i}") for i, img in enumerate(img_lst)]
util.plot_imgs(plt_lst, max_cols = 3)

# %%
# create list containing paths to images.  NOTE: paths should be relative, and cannot go higher than working dir (unless i am wrong)
img_path_lst2 = ['../'+'/'.join(img_path.split('/')[-2:]) for img_path in img_path_lst]

# create HTML str from list of snippets built from image path list above
imageMontage_html=''.join( ["<img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='%s' />" % str(s) for s in sorted(img_path_lst2) ])
display(HTML(imageMontage_html))
print(imageMontage_html)
# Out:
# <img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/UAT_array_01.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/UAT_array_02.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_23x25.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_24x24.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_26x28.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_38x40.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_big.png' />
# <img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/UAT_array_01.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/UAT_array_02.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_23x25.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_24x24.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_26x28.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_38x40.png' /><img style='width: 200px; margin: 1px; float: left; border: 2px solid black;' src='../images/uat_big.png' />

# %%
# Use HTML to plot full folder 
from pathlib import Path

sample_image_path = '../images'
img_path_list = [img_path for img_path in Path(sample_image_path).glob('**/*.png')]

imagesList=''.join( ["<img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='%s' />" % str(s) 
                 for s in sorted(img_path_list) ])
display(HTML(imagesList))
# Out:
# <img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/Dispenser Defects/1239519/Improperly Formed Channels.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/DispenserOpt_00097_2016-10-31_14.03.19.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/ROI_markers.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/ROI_markers2.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/UAT_array_01.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/UAT_array_02.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/checkerboard1.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/checkerboard_barrel.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/checkerboard_normal.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/checkerboard_pincushion.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/lena-16g.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/uat.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/uat_23x25.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/uat_24x24.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/uat_26x28.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/uat_38x40.png' /><img style='width: 120px; margin: 10px; float: left; border: 2px solid black;' src='../images/uat_big.png' />

# %% [markdown]
# ### Interactive Image view using pywidget 'interact'

# %%
from ipywidgets import interact

# %%
def browse_images(img_lst):
    n = len(img_lst)
    def view_image(i):
        plt.imshow(img_lst[i], cmap=plt.cm.gray_r, interpolation='nearest')
        plt.title('Image #: %d' % i)
        plt.show()
    interact(view_image, i=(0,n-1))

# %%
browse_images(img_lst)
